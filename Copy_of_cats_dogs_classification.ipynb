# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanuja2725/machinelearning/blob/main/Copy_of_cats_dogs_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 02nd Dec, 2022
# My folder: E:/cats_and_dogs/data
# Google drive: /content/drive/MyDrive/Colab_data_files
# Data folder:  '/home/tanuja/Images/cats_dogs/
# VM: lubuntu_deeplearning_I
#
# Objectives:
#           i)  Building powerful image classification models using
#               very little data
#           ii) Using image data-augmentation techniques
#           iii)Predicting cats and dogs--Kaggle
#               https://www.kaggle.com/c/dogs-vs-cats
#           iv) Calcualting model weights, stage-by-stage
#            v) Saving model-weights and model-architecture to files
#           vi) Loading saved model-architecture and model-weights

# %%
"""

A. Arrange your data first
==========================

    Download data from: https://www.kaggle.com/c/dogs-vs-cats/data .
    Unzip train.zip and arrange its files as follows:
        data/
            train/
                dogs/                      1000
                    dog001.jpg
                    dog002.jpg
                    ...
                    dog1000.jpg
                cats/                      1000
                    cat001.jpg
                    cat002.jpg
                    ...
                    cat1000.jpg
           validation/
               dogs/                        400
                   dog1001.jpg
                   dog1002.jpg
                   ...
                   dog1400.jpg
              cats/                         400
                  cat1001.jpg
                  cat1002.jpg
                  ...
                  cat1004.jpg

    So we are picking up only 1000 files of each category for training.
    Arrangement of (only) 'training' files in this fashion has an advantage that
    keras automatically knows which images are of cats and which images are
    of dogs. It does automatic labeling of images; we do not have to specify
    explicitly in the code for building training model. This automatic labelling
     is done by ImageGenerator.
# Out:
#   File "<ipython-input-2-61b41c1dd438>", line 37
#     is done by ImageGenerator.
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
"""
B. Training steps are as follows:
=================================

    1. Arrange training files as above. (Our total samples: nb_train_samples = 2000)
    2. Arrange validation files as above (Valid Samples: nb_validation_samples = 800)
    3. Specify location of all train folder and vaidation folder
    4. Depending upon your backend (tensorflow/theano) decide
       the shape/format of your input image arrays. This is needed in CNN modeling.
    5. Build the CNN model & compile it

    6. Use ImageDataGenerator to augment train images. This is in two steps:
        i)  Create an object with configuration of possible changes in any image
        ii) Use the object to create an iterator with following further configuration:
                a)  Create iterator using flow(), '.flow_from_directory()' method
            In '.flow_from_directory()', specify:
                b)   Where is the directory of your images?
            In ''.flow()' specify X_train, y_train
            Further in both cases:
                b)  Do you also want to resize images, if so, specify these
                c)  What batch-size to augment and model at a time;depends upon RAM
                d)  Is classification binary or categorical?

    7. Use ImageDataGenerator to augment validation images. Again the two steps
       as above. But we only resize validation images.
    8. Begin extracting images or training using the iterator fit_generator():
        CNN fit_generator() takes these arguments:
        i)   train-data-iterator (batch-wise source of train images)
        ii)  validation-data generator (batch-wise source of validation images)
        iii) no of epochs


   9. After training has finished, save model weights to a '.h5' file and also
      save model configuration to a json file.


   ------------
   Later, maybe, after some time
   10.Unzip test data file in a folder (within another folder. This is impt.).
   11.Configure test Image Data Generator
   12.Use above configuration and test-folder address, to create a test generator
   13.Load saved cnn model and load network weights in this model from saved h5 file
   14.Use predict() to make predictions on test_generator.
   15.Evaluate predictions

"""

# %%
"""
C. About keras backend:
=======================

    The default keras configuration file is in folder:
        C:\Users\ashokharnal\.keras.  It looks like as below.
        The configurtion is as per the installed backend on your machine:
        tensorflow, theano or CNTK

            {
                    "image_data_format": "channels_last",
                    "epsilon": 1e-07,
                    "floatx": "float32",
                    "backend": "tensorflow"
                    }

            "epsilon" is used instead of zero when division is by zero. 'floatx'
            specifies the datatype that keras will process.
            For 2D data (e.g. image), "channels_last" assumes (rows,cols,channels)
            while "channels_first" assumes (channels,rows,cols)
            (channels stand for RGB colour channels)
"""
# Out:
#   File "<ipython-input-3-2dc921124fec>", line 1
#     """
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 115-116: truncated \UXXXXXXXX escape

# %%
"""
D. Prerequisites:
=================
    Before attempting this problem, pl study Image Augmentation in Moodle at
    http://203.122.28.230/moodle/course/view.php?id=11&sectionid=166#section-9

E. Note
=======
    This is a full code from building model to making predictions for test data.
    AUC is very less as no. of training epochs are just 5. The training consumes
    time but very less memory (around 50%) on an 8GB machine. Vary batch size
    to control memory usage.


F. Make theano as backend
=========================

#    cp /home/ashok/.keras/keras_theano.json  /home/ashok/.keras/keras.json
#    cat /home/ashok/.keras/keras.json
#    source deactivate tensorflow
#    source activate theano
#    ipython
	In file:  ~/.keras/keras.json, set:

	"backend": "theano",    # instead of "tensorflow"

         Also the following environment variable needs to be set in bashrc:

	 export "MKL_THREADING_LAYER=GNU"

'''
# Out:
#   File "<ipython-input-4-979e01d29a57>", line 31
#     '''
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
"""

TODO: Use livelossplot
GitHub: https://github.com/stared/livelossplot
SEE example:
https://colab.research.google.com/github/stared/livelossplot/blob/master/examples/keras.ipynb


"""
# Out:
# '\n\nTODO: Use livelossplot\nGitHub: https://github.com/stared/livelossplot\nSEE example:\nhttps://colab.research.google.com/github/stared/livelossplot/blob/master/examples/keras.ipynb\n\n\n'

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Unmount drive, if mounted:

from google.colab import drive
drive.flush_and_unmount()

# %%
#@title Example form fields
#@markdown Forms support many types of fields.

no_type_checking = ''  #@param
string_type = 'example'  #@param {type: "string"}
slider_value = 142  #@param {type: "slider", min: 100, max: 200}
number = 102  #@param {type: "number"}
date = '2010-11-05'  #@param {type: "date"}
pick_me = "monday"  #@param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" #@param ["apples", "bananas", "oranges"] {allow-input: true}
#@markdown ---

# %%
# Mount drive at /gdrive:

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#%%                                A. Call libraries

#        $ source activate theano
#        $ ipython
# OR in Windows
#       > conda activate tensorflow_env
#       > atom

# 0. Release memory
# %reset -f

# 1.0 Data manipulation library
#     Install in 'tf' environment
#     conda install -c anaconda pandas
import pandas as pd
import tensorflow as tf

# 1.1 Call libraries for image processing
#     Another preprocessing option is text and sequence
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1.2, Libraries for building sequential CNN model
#      A model is composed of sequence of layered objects
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Input

# 1.3.Keras has three backend implementations available: the TensorFlow,
#    the Theano, and CNTK backend.
"""
What is a "backend"?
(http://faroit.com/keras-docs/1.2.0/backend/)
    Keras is a model-level library, providing high-level building blocks
    for developing deep learning models. It does not handle itself low-level
    operations such as tensor products, convolutions and so on. Instead,
    it relies on a specialized, well-optimized tensor manipulation library
    to do so, serving as the "backend engine" of Keras.
    List of low-level functions:
    https://www.tensorflow.org/api_docs/python/tf/keras/backend
"""
from tensorflow.keras import backend as K

# 1.4 Save CNN model configuration
from tensorflow.keras.models import model_from_json

# 1.5 OS related
import os

# 1.6 For ROC plotting
import matplotlib.pyplot as plt

# 1.7
import numpy as np
# conda install scikit-learn
from sklearn import metrics
import time
#from skimage import exposure           # Not used

# 1.8
# conda install -c anaconda pillow
#  Then deactivate and activate environment
#   This step is a must here
from PIL import Image                  # Needed in Windows
# Out:
# '\nWhat is a "backend"?\n(http://faroit.com/keras-docs/1.2.0/backend/)\n    Keras is a model-level library, providing high-level building blocks\n    for developing deep learning models. It does not handle itself low-level\n    operations such as tensor products, convolutions and so on. Instead,\n    it relies on a specialized, well-optimized tensor manipulation library\n    to do so, serving as the "backend engine" of Keras.\n    List of low-level functions:\n    https://www.tensorflow.org/api_docs/python/tf/keras/backend\n'

# %%
# 1.9 Make two folders, one for .tar.gz file
#     and the other for unzipped files
! mkdir /root/catsdogs
! mkdir /root/tanuja
# Out:
# mkdir: cannot create directory ‘/root/catsdogs’: File exists
# mkdir: cannot create directory ‘/root/tanuja’: File exists

# %%
# 1.10 Copy tar.gz file from Google drive to Virtual machine
! cp /gdrive/MyDrive/colab_data_files/catsdogs/*.*  /root/catsdogs

# 1.11 And check
! ls /root/catsdogs
# Out:
# cats_dogs.tar.gz

# %%
# 1.12 Untar file to folder /root/tanuja/ :

! tar -xvf /root/catsdogs/cats_dogs.tar.gz  -C /root/tanuja
# Out:
# cats_dogs/train/cats/cat.637.jpg
# cats_dogs/train/cats/cat.540.jpg
# cats_dogs/validation/cats/cat.1374.jpg
# cats_dogs/train/dogs/dog.95.jpg
# cats_dogs/validation/dogs/dog.1297.jpg
# cats_dogs/train/cats/cat.698.jpg
# cats_dogs/train/cats/cat.828.jpg
# cats_dogs/train/cats/cat.54.jpg
# cats_dogs/train/cats/cat.249.jpg
# cats_dogs/validation/cats/cat.1116.jpg
# cats_dogs/train/dogs/dog.257.jpg
# cats_dogs/validation/dogs/dog.1039.jpg
# cats_dogs/train/cats/cat.152.jpg
# cats_dogs/train/dogs/dog.984.jpg
# cats_dogs/train/cats/cat.1000.jpg
# cats_dogs/validation/dogs/dog.1220.jpg
# cats_dogs/validation/cats/cat.1177.jpg
# cats_dogs/train/cats/cat.909.jpg
# cats_dogs/train/cats/cat.873.jpg
# cats_dogs/train/dogs/dog.726.jpg
# cats_dogs/train/cats/cat.621.jpg
# cats_dogs/validation/dogs/dog.1281.jpg
# cats_dogs/train/dogs/dog.917.jpg
# cats_dogs/train/cats/cat.812.jpg
# cats_dogs/test/test/234.jpg
# cats_dogs/validation/cats/cat.1100.jpg
# cats_dogs/train/dogs/dog.787.jpg
# cats_dogs/train/dogs/dog.241.jpg
# cats_dogs/validation/dogs/dog.1023.jpg
# cats_dogs/train/dogs/dog.338.jpg
# cats_dogs/train/cats/cat.233.jpg
# cats_dogs/train/dogs/dog.399.jpg
# cats_dogs/train/cats/cat.424.jpg
# cats_dogs/train/dogs/dog.529.jpg
# cats_dogs/validation/cats/cat.1161.jpg
# cats_dogs/test/test/295.jpg
# cats_dogs/validation/dogs/dog.1084.jpg
# cats_dogs/train/dogs/dog.710.jpg
# cats_dogs/train/cats/cat.294.jpg
# cats_dogs/train/dogs/dog.901.jpg
# cats_dogs/train/cats/cat.485.jpg
# cats_dogs/test/test/16.jpg
# cats_dogs/train/dogs/dog.771.jpg
# cats_dogs/train/dogs/dog.322.jpg
# cats_dogs/test/test/77.jpg
# cats_dogs/train/dogs/dog.513.jpg
# cats_dogs/train/cats/cat.954.jpg
# cats_dogs/train/dogs/dog.383.jpg
# cats_dogs/train/dogs/dog.574.jpg
# cats_dogs/validation/dogs/dog.1356.jpg
# cats_dogs/train/dogs/dog.125.jpg
# cats_dogs/test/test/118.jpg
# cats_dogs/train/cats/cat.566.jpg
# cats_dogs/train/cats/cat.308.jpg
# cats_dogs/train/cats/cat.757.jpg
# cats_dogs/train/dogs/dog.186.jpg
# cats_dogs/validation/cats/cat.1045.jpg
# cats_dogs/test/test/61.jpg
# cats_dogs/test/test/179.jpg
# cats_dogs/validation/cats/cat.1236.jpg
# cats_dogs/validation/dogs/dog.1159.jpg
# cats_dogs/train/cats/cat.369.jpg
# cats_dogs/validation/dogs/dog.1340.jpg
# cats_dogs/train/dogs/dog.655.jpg
# cats_dogs/test/test/102.jpg
# cats_dogs/train/cats/cat.550.jpg
# cats_dogs/train/dogs/dog.846.jpg
# cats_dogs/train/cats/cat.741.jpg
# cats_dogs/train/dogs/dog.170.jpg
# cats_dogs/test/test/163.jpg
# cats_dogs/validation/cats/cat.1317.jpg
# cats_dogs/validation/cats/cat.1220.jpg
# cats_dogs/train/dogs/dog.38.jpg
# cats_dogs/validation/dogs/dog.1143.jpg
# cats_dogs/train/dogs/dog.458.jpg
# cats_dogs/validation/cats/cat.1090.jpg
# cats_dogs/train/cats/cat.353.jpg
# cats_dogs/train/cats/cat.544.jpg
# cats_dogs/validation/cats/cat.1378.jpg
# cats_dogs/train/dogs/dog.830.jpg
# cats_dogs/train/dogs/dog.99.jpg
# cats_dogs/train/cats/cat.58.jpg
# cats_dogs/train/cats/cat.156.jpg
# cats_dogs/train/dogs/dog.988.jpg
# cats_dogs/train/dogs/dog.891.jpg
# cats_dogs/train/dogs/dog.22.jpg
# cats_dogs/validation/cats/cat.1301.jpg
# cats_dogs/train/dogs/dog.442.jpg
# cats_dogs/validation/dogs/dog.1224.jpg
# cats_dogs/train/cats/cat.861.jpg
# cats_dogs/train/cats/cat.625.jpg
# cats_dogs/train/cats/cat.816.jpg
# cats_dogs/validation/cats/cat.1362.jpg
# cats_dogs/train/dogs/dog.83.jpg
# cats_dogs/validation/dogs/dog.1285.jpg
# cats_dogs/train/cats/cat.877.jpg
# cats_dogs/train/cats/cat.42.jpg
# cats_dogs/train/dogs/dog.245.jpg
# cats_dogs/train/cats/cat.686.jpg
# cats_dogs/validation/cats/cat.1104.jpg
# cats_dogs/test/test/238.jpg
# cats_dogs/validation/dogs/dog.1027.jpg
# cats_dogs/train/cats/cat.140.jpg
# cats_dogs/train/dogs/dog.972.jpg
# cats_dogs/train/cats/cat.237.jpg
# cats_dogs/train/cats/cat.428.jpg
# cats_dogs/validation/cats/cat.1165.jpg
# cats_dogs/test/test/299.jpg
# cats_dogs/validation/dogs/dog.1088.jpg
# cats_dogs/train/dogs/dog.714.jpg
# cats_dogs/train/cats/cat.958.jpg
# cats_dogs/train/cats/cat.298.jpg
# cats_dogs/train/dogs/dog.905.jpg
# cats_dogs/train/cats/cat.800.jpg
# cats_dogs/train/cats/cat.489.jpg
# cats_dogs/train/cats/cat.670.jpg
# cats_dogs/train/dogs/dog.775.jpg
# cats_dogs/test/test/222.jpg
# cats_dogs/validation/dogs/dog.1011.jpg
# cats_dogs/train/dogs/dog.326.jpg
# cats_dogs/train/cats/cat.221.jpg
# cats_dogs/train/cats/cat.412.jpg
# cats_dogs/train/dogs/dog.517.jpg
# cats_dogs/train/dogs/dog.290.jpg
# cats_dogs/test/test/283.jpg
# cats_dogs/validation/dogs/dog.1072.jpg
# cats_dogs/train/dogs/dog.387.jpg
# cats_dogs/train/cats/cat.282.jpg
# cats_dogs/train/dogs/dog.578.jpg
# cats_dogs/train/cats/cat.473.jpg
# cats_dogs/train/dogs/dog.129.jpg
# cats_dogs/train/cats/cat.942.jpg
# cats_dogs/train/dogs/dog.310.jpg
# cats_dogs/test/test/65.jpg
# cats_dogs/validation/cats/cat.1049.jpg
# cats_dogs/train/dogs/dog.501.jpg
# cats_dogs/test/test/106.jpg
# cats_dogs/train/dogs/dog.371.jpg
# cats_dogs/validation/cats/cat.1291.jpg
# cats_dogs/train/dogs/dog.562.jpg
# cats_dogs/validation/dogs/dog.1344.jpg
# cats_dogs/train/dogs/dog.659.jpg
# cats_dogs/train/dogs/dog.113.jpg
# cats_dogs/train/cats/cat.554.jpg
# cats_dogs/train/cats/cat.745.jpg
# cats_dogs/validation/cats/cat.1033.jpg
# cats_dogs/test/test/167.jpg
# cats_dogs/train/dogs/dog.174.jpg
# cats_dogs/validation/cats/cat.1224.jpg
# cats_dogs/validation/dogs/dog.1147.jpg
# cats_dogs/validation/cats/cat.1094.jpg
# cats_dogs/train/cats/cat.357.jpg
# cats_dogs/train/dogs/dog.643.jpg
# cats_dogs/train/cats/cat.548.jpg
# cats_dogs/train/dogs/dog.834.jpg
# cats_dogs/train/cats/cat.629.jpg
# cats_dogs/test/test/151.jpg
# cats_dogs/validation/dogs/dog.1228.jpg
# cats_dogs/train/cats/cat.790.jpg
# cats_dogs/train/dogs/dog.895.jpg
# cats_dogs/validation/dogs/dog.1131.jpg
# cats_dogs/validation/cats/cat.1305.jpg
# cats_dogs/train/dogs/dog.446.jpg
# cats_dogs/train/dogs/dog.26.jpg
# cats_dogs/train/cats/cat.341.jpg
# cats_dogs/train/cats/cat.532.jpg
# cats_dogs/validation/dogs/dog.1192.jpg
# cats_dogs/validation/cats/cat.1366.jpg
# cats_dogs/validation/dogs/dog.1289.jpg
# cats_dogs/train/dogs/dog.87.jpg
# cats_dogs/train/cats/cat.804.jpg
# cats_dogs/train/cats/cat.91.jpg
# cats_dogs/train/cats/cat.46.jpg
# cats_dogs/validation/cats/cat.1108.jpg
# cats_dogs/train/dogs/dog.249.jpg
# cats_dogs/train/cats/cat.144.jpg
# cats_dogs/validation/dogs/dog.1212.jpg
# cats_dogs/train/dogs/dog.976.jpg
# cats_dogs/train/dogs/dog.430.jpg
# cats_dogs/train/dogs/dog.10.jpg
# cats_dogs/train/cats/cat.613.jpg
# cats_dogs/validation/cats/cat.1169.jpg
# cats_dogs/train/dogs/dog.718.jpg
# cats_dogs/validation/dogs/dog.1273.jpg
# cats_dogs/validation/cats/cat.1350.jpg
# cats_dogs/train/dogs/dog.491.jpg
# cats_dogs/train/dogs/dog.71.jpg
# cats_dogs/train/dogs/dog.909.jpg
# cats_dogs/train/cats/cat.30.jpg
# cats_dogs/test/test/226.jpg
# cats_dogs/train/cats/cat.674.jpg
# cats_dogs/train/dogs/dog.779.jpg
# cats_dogs/train/dogs/dog.233.jpg
# cats_dogs/validation/dogs/dog.1015.jpg
# cats_dogs/train/cats/cat.865.jpg
# cats_dogs/train/dogs/dog.960.jpg
# cats_dogs/train/cats/cat.225.jpg
# cats_dogs/train/cats/cat.416.jpg
# cats_dogs/validation/cats/cat.1153.jpg
# cats_dogs/test/test/287.jpg
# cats_dogs/train/dogs/dog.294.jpg
# cats_dogs/validation/dogs/dog.1076.jpg
# cats_dogs/train/dogs/dog.702.jpg
# cats_dogs/train/cats/cat.286.jpg
# cats_dogs/train/cats/cat.477.jpg
# cats_dogs/train/dogs/dog.763.jpg
# cats_dogs/test/test/210.jpg
# cats_dogs/train/dogs/dog.314.jpg
# cats_dogs/train/cats/cat.946.jpg
# cats_dogs/test/test/69.jpg
# cats_dogs/train/dogs/dog.505.jpg
# cats_dogs/train/cats/cat.400.jpg
# cats_dogs/test/test/271.jpg
# cats_dogs/validation/dogs/dog.1060.jpg
# cats_dogs/train/dogs/dog.375.jpg
# cats_dogs/train/cats/cat.270.jpg
# cats_dogs/train/cats/cat.461.jpg
# cats_dogs/train/dogs/dog.566.jpg
# cats_dogs/validation/dogs/dog.1348.jpg
# cats_dogs/train/dogs/dog.117.jpg
# cats_dogs/validation/cats/cat.1295.jpg
# cats_dogs/train/cats/cat.558.jpg
# cats_dogs/train/cats/cat.794.jpg
# cats_dogs/train/cats/cat.749.jpg
# cats_dogs/test/test/53.jpg
# cats_dogs/validation/cats/cat.1037.jpg
# cats_dogs/train/dogs/dog.178.jpg
# cats_dogs/train/cats/cat.930.jpg
# cats_dogs/validation/cats/cat.1228.jpg
# cats_dogs/train/cats/cat.991.jpg
# cats_dogs/validation/cats/cat.1098.jpg
# cats_dogs/train/dogs/dog.550.jpg
# cats_dogs/validation/dogs/dog.1332.jpg
# cats_dogs/train/dogs/dog.647.jpg
# cats_dogs/train/dogs/dog.101.jpg
# cats_dogs/train/dogs/dog.838.jpg
# cats_dogs/train/cats/cat.733.jpg
# cats_dogs/train/dogs/dog.162.jpg
# cats_dogs/validation/dogs/dog.1393.jpg
# cats_dogs/validation/cats/cat.1021.jpg
# cats_dogs/test/test/155.jpg
# cats_dogs/validation/cats/cat.1212.jpg
# cats_dogs/train/dogs/dog.899.jpg
# cats_dogs/validation/dogs/dog.1135.jpg
# cats_dogs/validation/cats/cat.1309.jpg
# cats_dogs/validation/cats/cat.1082.jpg
# cats_dogs/train/cats/cat.345.jpg
# cats_dogs/train/dogs/dog.631.jpg
# cats_dogs/train/cats/cat.536.jpg
# cats_dogs/validation/dogs/dog.1196.jpg
# cats_dogs/train/dogs/dog.822.jpg
# cats_dogs/train/cats/cat.808.jpg
# cats_dogs/train/dogs/dog.692.jpg
# cats_dogs/train/cats/cat.148.jpg
# cats_dogs/train/dogs/dog.883.jpg
# cats_dogs/validation/dogs/dog.1216.jpg
# cats_dogs/train/cats/cat.95.jpg
# cats_dogs/train/dogs/dog.434.jpg
# cats_dogs/train/dogs/dog.14.jpg
# cats_dogs/train/cats/cat.617.jpg
# cats_dogs/validation/dogs/dog.1180.jpg
# cats_dogs/train/cats/cat.520.jpg
# cats_dogs/train/dogs/dog.75.jpg
# cats_dogs/validation/cats/cat.1354.jpg
# cats_dogs/train/dogs/dog.495.jpg
# cats_dogs/validation/dogs/dog.1277.jpg
# cats_dogs/train/cats/cat.390.jpg
# cats_dogs/train/cats/cat.853.jpg
# cats_dogs/train/cats/cat.34.jpg
# cats_dogs/train/cats/cat.678.jpg
# cats_dogs/train/cats/cat.869.jpg
# cats_dogs/train/dogs/dog.237.jpg
# cats_dogs/validation/dogs/dog.1019.jpg
# cats_dogs/train/cats/cat.132.jpg
# cats_dogs/train/dogs/dog.964.jpg
# cats_dogs/train/cats/cat.229.jpg
# cats_dogs/validation/dogs/dog.1200.jpg
# cats_dogs/validation/cats/cat.1157.jpg
# cats_dogs/train/dogs/dog.298.jpg
# cats_dogs/train/cats/cat.193.jpg
# cats_dogs/train/dogs/dog.706.jpg
# cats_dogs/train/cats/cat.601.jpg
# cats_dogs/train/cats/cat.404.jpg
# cats_dogs/validation/dogs/dog.1261.jpg
# cats_dogs/train/cats/cat.662.jpg
# cats_dogs/train/dogs/dog.767.jpg
# cats_dogs/train/dogs/dog.221.jpg
# cats_dogs/test/test/214.jpg
# cats_dogs/validation/dogs/dog.1003.jpg
# cats_dogs/train/dogs/dog.318.jpg
# cats_dogs/train/cats/cat.83.jpg
# cats_dogs/train/cats/cat.213.jpg
# cats_dogs/train/dogs/dog.282.jpg
# cats_dogs/train/dogs/dog.509.jpg
# cats_dogs/validation/cats/cat.1141.jpg
# cats_dogs/test/test/275.jpg
# cats_dogs/validation/dogs/dog.1064.jpg
# cats_dogs/train/dogs/dog.379.jpg
# cats_dogs/train/cats/cat.274.jpg
# cats_dogs/train/dogs/dog.266.jpg
# cats_dogs/validation/dogs/dog.1048.jpg
# cats_dogs/train/cats/cat.161.jpg
# cats_dogs/train/dogs/dog.993.jpg
# cats_dogs/train/cats/cat.258.jpg
# cats_dogs/train/cats/cat.691.jpg
# cats_dogs/validation/cats/cat.1186.jpg
# cats_dogs/train/cats/cat.449.jpg
# cats_dogs/train/cats/cat.882.jpg
# cats_dogs/train/dogs/dog.735.jpg
# cats_dogs/train/cats/cat.979.jpg
# cats_dogs/train/cats/cat.630.jpg
# cats_dogs/validation/dogs/dog.1290.jpg
# cats_dogs/train/dogs/dog.926.jpg
# cats_dogs/train/cats/cat.918.jpg
# cats_dogs/train/cats/cat.821.jpg
# cats_dogs/train/dogs/dog.796.jpg
# cats_dogs/train/dogs/dog.250.jpg
# cats_dogs/test/test/243.jpg
# cats_dogs/validation/dogs/dog.1032.jpg
# cats_dogs/train/dogs/dog.347.jpg
# cats_dogs/train/cats/cat.242.jpg
# cats_dogs/train/cats/cat.433.jpg
# cats_dogs/train/dogs/dog.538.jpg
# cats_dogs/validation/cats/cat.1170.jpg
# cats_dogs/validation/dogs/dog.1093.jpg
# cats_dogs/validation/cats/cat.1267.jpg
# cats_dogs/train/cats/cat.494.jpg
# cats_dogs/train/dogs/dog.910.jpg
# cats_dogs/train/dogs/dog.599.jpg
# cats_dogs/test/test/25.jpg
# cats_dogs/validation/cats/cat.1009.jpg
# cats_dogs/train/cats/cat.902.jpg
# cats_dogs/train/dogs/dog.780.jpg
# cats_dogs/train/cats/cat.963.jpg
# cats_dogs/train/dogs/dog.331.jpg
# cats_dogs/train/dogs/dog.9.jpg
# cats_dogs/test/test/86.jpg
# cats_dogs/train/dogs/dog.522.jpg
# cats_dogs/validation/dogs/dog.1304.jpg
# cats_dogs/train/dogs/dog.619.jpg
# cats_dogs/train/dogs/dog.392.jpg
# cats_dogs/train/cats/cat.766.jpg
# cats_dogs/train/cats/cat.705.jpg
# cats_dogs/train/dogs/dog.583.jpg
# cats_dogs/validation/dogs/dog.1365.jpg
# cats_dogs/train/dogs/dog.134.jpg
# cats_dogs/test/test/127.jpg
# cats_dogs/train/cats/cat.575.jpg
# cats_dogs/train/cats/cat.317.jpg
# cats_dogs/validation/dogs/dog.1107.jpg
# cats_dogs/train/dogs/dog.195.jpg
# cats_dogs/test/test/70.jpg
# cats_dogs/validation/cats/cat.1054.jpg
# cats_dogs/test/test/188.jpg
# cats_dogs/train/dogs/dog.603.jpg
# cats_dogs/validation/cats/cat.1245.jpg
# cats_dogs/train/cats/cat.508.jpg
# cats_dogs/validation/dogs/dog.1168.jpg
# cats_dogs/train/cats/cat.378.jpg
# cats_dogs/train/dogs/dog.664.jpg
# cats_dogs/test/test/111.jpg
# cats_dogs/train/dogs/dog.855.jpg
# cats_dogs/train/cats/cat.750.jpg
# cats_dogs/train/dogs/dog.406.jpg
# cats_dogs/train/cats/cat.301.jpg
# cats_dogs/test/test/172.jpg
# cats_dogs/validation/dogs/dog.1152.jpg
# cats_dogs/train/dogs/dog.122.jpg
# cats_dogs/train/dogs/dog.571.jpg
# cats_dogs/validation/dogs/dog.1353.jpg
# cats_dogs/train/dogs/dog.668.jpg
# cats_dogs/test/test/115.jpg
# cats_dogs/train/cats/cat.563.jpg
# cats_dogs/train/cats/cat.683.jpg
# cats_dogs/train/dogs/dog.859.jpg
# cats_dogs/train/cats/cat.754.jpg
# cats_dogs/train/cats/cat.305.jpg
# cats_dogs/validation/cats/cat.1042.jpg
# cats_dogs/test/test/176.jpg
# cats_dogs/train/dogs/dog.183.jpg
# cats_dogs/validation/cats/cat.1233.jpg
# cats_dogs/validation/dogs/dog.1156.jpg
# cats_dogs/train/cats/cat.366.jpg
# cats_dogs/train/dogs/dog.652.jpg
# cats_dogs/train/dogs/dog.843.jpg
# cats_dogs/train/cats/cat.108.jpg
# cats_dogs/test/test/160.jpg
# cats_dogs/train/dogs/dog.35.jpg
# cats_dogs/train/cats/cat.169.jpg
# cats_dogs/validation/dogs/dog.1140.jpg
# cats_dogs/validation/cats/cat.1314.jpg
# cats_dogs/train/dogs/dog.455.jpg
# cats_dogs/validation/dogs/dog.1237.jpg
# cats_dogs/train/cats/cat.350.jpg
# cats_dogs/train/cats/cat.638.jpg
# cats_dogs/train/cats/cat.541.jpg
# cats_dogs/validation/cats/cat.1375.jpg
# cats_dogs/train/dogs/dog.96.jpg
# cats_dogs/validation/dogs/dog.1298.jpg
# cats_dogs/train/cats/cat.829.jpg
# cats_dogs/train/cats/cat.55.jpg
# cats_dogs/validation/cats/cat.1117.jpg
# cats_dogs/train/dogs/dog.258.jpg
# cats_dogs/train/cats/cat.699.jpg
# cats_dogs/train/cats/cat.153.jpg
# cats_dogs/train/dogs/dog.985.jpg
# cats_dogs/validation/dogs/dog.1221.jpg
# cats_dogs/validation/cats/cat.1178.jpg
# cats_dogs/train/cats/cat.874.jpg
# cats_dogs/train/dogs/dog.727.jpg
# cats_dogs/train/cats/cat.622.jpg
# cats_dogs/train/dogs/dog.80.jpg
# cats_dogs/validation/dogs/dog.1282.jpg
# cats_dogs/train/dogs/dog.918.jpg
# cats_dogs/train/cats/cat.813.jpg
# cats_dogs/train/dogs/dog.242.jpg
# cats_dogs/train/dogs/dog.788.jpg
# cats_dogs/validation/cats/cat.1101.jpg
# cats_dogs/test/test/235.jpg
# cats_dogs/validation/dogs/dog.1024.jpg
# cats_dogs/train/dogs/dog.339.jpg
# cats_dogs/train/cats/cat.234.jpg
# cats_dogs/train/cats/cat.425.jpg
# cats_dogs/validation/cats/cat.1162.jpg
# cats_dogs/test/test/296.jpg
# cats_dogs/validation/dogs/dog.1085.jpg
# cats_dogs/train/dogs/dog.711.jpg
# cats_dogs/train/cats/cat.295.jpg
# cats_dogs/train/dogs/dog.902.jpg
# cats_dogs/train/cats/cat.486.jpg
# cats_dogs/test/test/17.jpg
# cats_dogs/train/dogs/dog.772.jpg
# cats_dogs/train/dogs/dog.323.jpg
# cats_dogs/test/test/78.jpg
# cats_dogs/train/cats/cat.610.jpg
# cats_dogs/train/cats/cat.299.jpg
# cats_dogs/validation/dogs/dog.1270.jpg
# cats_dogs/train/dogs/dog.906.jpg
# cats_dogs/train/cats/cat.801.jpg
# cats_dogs/test/test/223.jpg
# cats_dogs/train/cats/cat.671.jpg
# cats_dogs/train/dogs/dog.776.jpg
# cats_dogs/train/dogs/dog.230.jpg
# cats_dogs/validation/dogs/dog.1012.jpg
# cats_dogs/train/dogs/dog.327.jpg
# cats_dogs/train/cats/cat.222.jpg
# cats_dogs/validation/cats/cat.1150.jpg
# cats_dogs/train/cats/cat.413.jpg
# cats_dogs/train/dogs/dog.518.jpg
# cats_dogs/test/test/284.jpg
# cats_dogs/train/dogs/dog.291.jpg
# cats_dogs/validation/dogs/dog.1073.jpg
# cats_dogs/train/dogs/dog.388.jpg
# cats_dogs/train/cats/cat.283.jpg
# cats_dogs/train/dogs/dog.579.jpg
# cats_dogs/train/cats/cat.474.jpg
# cats_dogs/train/dogs/dog.760.jpg
# cats_dogs/train/dogs/dog.311.jpg
# cats_dogs/test/test/66.jpg
# cats_dogs/train/dogs/dog.502.jpg
# cats_dogs/train/cats/cat.943.jpg
# cats_dogs/train/dogs/dog.372.jpg
# cats_dogs/train/dogs/dog.114.jpg
# cats_dogs/train/dogs/dog.563.jpg
# cats_dogs/validation/dogs/dog.1345.jpg
# cats_dogs/test/test/107.jpg
# cats_dogs/validation/cats/cat.1292.jpg
# cats_dogs/train/cats/cat.555.jpg
# cats_dogs/train/cats/cat.746.jpg
# cats_dogs/train/dogs/dog.175.jpg
# cats_dogs/validation/cats/cat.1034.jpg
# cats_dogs/test/test/50.jpg
# cats_dogs/test/test/168.jpg
# cats_dogs/validation/cats/cat.1225.jpg
# cats_dogs/validation/dogs/dog.1148.jpg
# cats_dogs/validation/cats/cat.1095.jpg
# cats_dogs/train/cats/cat.358.jpg
# cats_dogs/train/cats/cat.92.jpg
# cats_dogs/train/dogs/dog.644.jpg
# cats_dogs/train/cats/cat.549.jpg
# cats_dogs/train/dogs/dog.835.jpg
# cats_dogs/train/cats/cat.730.jpg
# cats_dogs/validation/dogs/dog.1390.jpg
# cats_dogs/train/cats/cat.791.jpg
# cats_dogs/test/test/152.jpg
# cats_dogs/validation/cats/cat.1306.jpg
# cats_dogs/train/dogs/dog.896.jpg
# cats_dogs/train/dogs/dog.27.jpg
# cats_dogs/validation/dogs/dog.1132.jpg
# cats_dogs/train/dogs/dog.447.jpg
# cats_dogs/validation/dogs/dog.1229.jpg
# cats_dogs/train/cats/cat.342.jpg
# cats_dogs/train/cats/cat.866.jpg
# cats_dogs/train/cats/cat.533.jpg
# cats_dogs/validation/dogs/dog.1193.jpg
# cats_dogs/validation/cats/cat.1367.jpg
# cats_dogs/train/dogs/dog.88.jpg
# cats_dogs/train/cats/cat.145.jpg
# cats_dogs/train/cats/cat.47.jpg
# cats_dogs/validation/cats/cat.1109.jpg
# cats_dogs/train/dogs/dog.880.jpg
# cats_dogs/train/dogs/dog.11.jpg
# cats_dogs/train/cats/cat.1.jpg
# cats_dogs/validation/cats/cat.1083.jpg
# cats_dogs/train/cats/cat.346.jpg
# cats_dogs/train/cats/cat.80.jpg
# cats_dogs/train/dogs/dog.632.jpg
# cats_dogs/train/cats/cat.537.jpg
# cats_dogs/validation/dogs/dog.1197.jpg
# cats_dogs/train/dogs/dog.823.jpg
# cats_dogs/train/dogs/dog.693.jpg
# cats_dogs/test/test/140.jpg
# cats_dogs/train/cats/cat.149.jpg
# cats_dogs/train/dogs/dog.884.jpg
# cats_dogs/validation/dogs/dog.1217.jpg
# cats_dogs/validation/dogs/dog.1120.jpg
# cats_dogs/train/dogs/dog.435.jpg
# cats_dogs/train/dogs/dog.15.jpg
# cats_dogs/train/cats/cat.330.jpg
# cats_dogs/validation/dogs/dog.1278.jpg
# cats_dogs/train/cats/cat.521.jpg
# cats_dogs/validation/dogs/dog.1181.jpg
# cats_dogs/validation/cats/cat.1355.jpg
# cats_dogs/train/dogs/dog.496.jpg
# cats_dogs/train/dogs/dog.76.jpg
# cats_dogs/train/cats/cat.391.jpg
# cats_dogs/train/cats/cat.809.jpg
# cats_dogs/train/cats/cat.35.jpg
# cats_dogs/train/cats/cat.96.jpg
# cats_dogs/train/dogs/dog.238.jpg
# cats_dogs/train/cats/cat.679.jpg
# cats_dogs/train/cats/cat.133.jpg
# cats_dogs/train/dogs/dog.965.jpg
# cats_dogs/train/cats/cat.194.jpg
# cats_dogs/validation/dogs/dog.1201.jpg
# cats_dogs/validation/cats/cat.1158.jpg
# cats_dogs/test/
# cats_dogs/train/dogs/dog.299.jpg
# cats_dogs/train/dogs/dog.707.jpg
# cats_dogs/validation/dogs/dog.1262.jpg
# cats_dogs/train/cats/cat.602.jpg
# cats_dogs/train/dogs/dog.480.jpg
# cats_dogs/train/dogs/dog.60.jpg
# cats_dogs/train/cats/cat.854.jpg
# cats_dogs/train/dogs/dog.222.jpg
# cats_dogs/train/cats/cat.663.jpg
# cats_dogs/train/dogs/dog.768.jpg
# cats_dogs/test/test/215.jpg
# cats_dogs/validation/dogs/dog.1004.jpg
# cats_dogs/train/dogs/dog.319.jpg
# cats_dogs/train/cats/cat.214.jpg
# cats_dogs/train/cats/cat.405.jpg
# cats_dogs/validation/cats/cat.1142.jpg
# cats_dogs/test/test/276.jpg
# cats_dogs/train/dogs/dog.283.jpg
# cats_dogs/validation/dogs/dog.1065.jpg
# cats_dogs/train/cats/cat.275.jpg
# cats_dogs/train/cats/cat.466.jpg
# cats_dogs/train/dogs/dog.752.jpg
# cats_dogs/train/dogs/dog.303.jpg
# cats_dogs/train/dogs/dog.943.jpg
# cats_dogs/train/cats/cat.783.jpg
# cats_dogs/test/test/58.jpg
# cats_dogs/train/cats/cat.935.jpg
# cats_dogs/test/test/260.jpg
# cats_dogs/train/dogs/dog.364.jpg
# cats_dogs/train/cats/cat.996.jpg
# cats_dogs/train/cats/cat.450.jpg
# cats_dogs/train/dogs/dog.555.jpg
# cats_dogs/validation/dogs/dog.1337.jpg
# cats_dogs/train/dogs/dog.612.jpg
# cats_dogs/validation/cats/cat.1254.jpg
# cats_dogs/train/cats/cat.517.jpg
# cats_dogs/validation/dogs/dog.1177.jpg
# cats_dogs/train/dogs/dog.803.jpg
# cats_dogs/train/cats/cat.387.jpg
# cats_dogs/train/dogs/dog.673.jpg
# cats_dogs/test/test/120.jpg
# cats_dogs/train/dogs/dog.864.jpg
# cats_dogs/train/cats/cat.129.jpg
# cats_dogs/validation/dogs/dog.1100.jpg
# cats_dogs/train/dogs/dog.415.jpg
# cats_dogs/train/cats/cat.310.jpg
# cats_dogs/test/test/181.jpg
# cats_dogs/validation/dogs/dog.1258.jpg
# cats_dogs/train/cats/cat.501.jpg
# cats_dogs/validation/dogs/dog.1161.jpg
# cats_dogs/validation/cats/cat.1335.jpg
# cats_dogs/train/dogs/dog.476.jpg
# cats_dogs/train/dogs/dog.56.jpg
# cats_dogs/train/cats/cat.371.jpg
# cats_dogs/train/cats/cat.15.jpg
# cats_dogs/validation/cats/cat.1396.jpg
# cats_dogs/train/dogs/dog.218.jpg
# cats_dogs/train/cats/cat.659.jpg
# cats_dogs/train/cats/cat.113.jpg
# cats_dogs/train/cats/cat.76.jpg
# cats_dogs/validation/cats/cat.1138.jpg
# cats_dogs/train/dogs/dog.279.jpg
# cats_dogs/train/cats/cat.174.jpg
# cats_dogs/validation/dogs/dog.1242.jpg
# cats_dogs/train/dogs/dog.460.jpg
# cats_dogs/train/dogs/dog.40.jpg
# cats_dogs/train/cats/cat.692.jpg
# cats_dogs/validation/cats/cat.1199.jpg
# cats_dogs/validation/cats/cat.1380.jpg
# cats_dogs/train/cats/cat.960.jpg
# cats_dogs/train/dogs/dog.748.jpg
# cats_dogs/train/dogs/dog.202.jpg
# cats_dogs/train/cats/cat.643.jpg
# cats_dogs/train/dogs/dog.939.jpg
# cats_dogs/train/cats/cat.834.jpg
# cats_dogs/train/cats/cat.60.jpg
# cats_dogs/validation/cats/cat.1122.jpg
# cats_dogs/test/test/256.jpg
# cats_dogs/train/dogs/dog.263.jpg
# cats_dogs/validation/dogs/dog.1045.jpg
# cats_dogs/train/dogs/dog.990.jpg
# cats_dogs/train/cats/cat.255.jpg
# cats_dogs/train/cats/cat.895.jpg
# cats_dogs/validation/cats/cat.1183.jpg
# cats_dogs/train/cats/cat.446.jpg
# cats_dogs/validation/dogs/
# cats_dogs/train/dogs/dog.732.jpg
# cats_dogs/train/dogs/
# cats_dogs/train/dogs/dog.923.jpg
# cats_dogs/train/cats/cat.915.jpg
# cats_dogs/test/test/38.jpg
# cats_dogs/train/cats/cat.430.jpg
# cats_dogs/train/dogs/dog.793.jpg
# cats_dogs/test/test/240.jpg
# cats_dogs/train/dogs/dog.344.jpg
# cats_dogs/train/cats/cat.976.jpg
# cats_dogs/test/test/99.jpg
# cats_dogs/train/dogs/dog.535.jpg
# cats_dogs/validation/dogs/dog.1317.jpg
# cats_dogs/validation/dogs/dog.1090.jpg
# cats_dogs/validation/cats/cat.1264.jpg
# cats_dogs/train/cats/cat.718.jpg
# cats_dogs/validation/dogs/dog.1378.jpg
# cats_dogs/train/cats/cat.491.jpg
# cats_dogs/train/dogs/dog.596.jpg
# cats_dogs/validation/cats/cat.1006.jpg
# cats_dogs/test/test/22.jpg
# cats_dogs/train/dogs/dog.147.jpg
# cats_dogs/train/cats/cat.588.jpg
# cats_dogs/train/cats/cat.763.jpg
# cats_dogs/train/cats/cat.779.jpg
# cats_dogs/validation/cats/cat.1067.jpg
# cats_dogs/test/test/83.jpg
# cats_dogs/validation/dogs/dog.1301.jpg
# cats_dogs/train/dogs/dog.6.jpg
# cats_dogs/train/dogs/dog.616.jpg
# cats_dogs/validation/cats/cat.1258.jpg
# cats_dogs/train/cats/cat.702.jpg
# cats_dogs/train/dogs/dog.807.jpg
# cats_dogs/train/dogs/dog.677.jpg
# cats_dogs/train/dogs/dog.580.jpg
# cats_dogs/validation/dogs/dog.1362.jpg
# cats_dogs/train/dogs/dog.131.jpg
# cats_dogs/test/test/124.jpg
# cats_dogs/train/cats/cat.572.jpg
# cats_dogs/train/cats/cat.314.jpg
# cats_dogs/train/dogs/dog.868.jpg
# cats_dogs/validation/dogs/dog.1104.jpg
# cats_dogs/train/dogs/dog.192.jpg
# cats_dogs/train/dogs/dog.419.jpg
# cats_dogs/validation/cats/cat.1051.jpg
# cats_dogs/test/test/185.jpg
# cats_dogs/train/cats/cat.505.jpg
# cats_dogs/train/dogs/dog.600.jpg
# ...
# cats_dogs/validation/dogs/dog.1199.jpg
# cats_dogs/train/dogs/dog.825.jpg
# cats_dogs/train/cats/cat.720.jpg
# cats_dogs/validation/dogs/dog.1380.jpg
# cats_dogs/train/dogs/dog.695.jpg
# cats_dogs/test/test/142.jpg
# cats_dogs/train/cats/cat.590.jpg
# cats_dogs/train/cats/cat.781.jpg
# cats_dogs/train/dogs/dog.886.jpg
# cats_dogs/validation/dogs/dog.1219.jpg
# cats_dogs/validation/dogs/dog.1122.jpg
# cats_dogs/train/dogs/dog.437.jpg
# cats_dogs/train/dogs/dog.17.jpg
# cats_dogs/train/cats/cat.332.jpg
# cats_dogs/train/cats/cat.523.jpg
# cats_dogs/validation/dogs/dog.1183.jpg
# cats_dogs/validation/cats/cat.1357.jpg
# cats_dogs/train/dogs/dog.498.jpg
# cats_dogs/train/dogs/dog.78.jpg
# cats_dogs/train/cats/cat.393.jpg
# cats_dogs/train/cats/cat.82.jpg
# cats_dogs/train/cats/cat.37.jpg
# cats_dogs/train/cats/cat.98.jpg
# cats_dogs/train/dogs/dog.870.jpg
# cats_dogs/train/cats/cat.135.jpg
# cats_dogs/train/dogs/dog.967.jpg
# cats_dogs/train/dogs/dog.421.jpg
# cats_dogs/validation/dogs/dog.1203.jpg
# cats_dogs/train/cats/cat.604.jpg
# cats_dogs/validation/dogs/dog.1264.jpg
# cats_dogs/train/cats/cat.196.jpg
# cats_dogs/train/dogs/dog.709.jpg
# cats_dogs/validation/cats/cat.1341.jpg
# cats_dogs/train/dogs/dog.482.jpg
# cats_dogs/train/cats/cat.836.jpg
# cats_dogs/train/cats/cat.62.jpg
# cats_dogs/train/dogs/dog.265.jpg
# cats_dogs/validation/cats/cat.1124.jpg
# cats_dogs/test/test/258.jpg
# cats_dogs/validation/dogs/dog.1047.jpg
# cats_dogs/train/cats/cat.160.jpg
# cats_dogs/train/dogs/dog.992.jpg
# cats_dogs/train/cats/cat.257.jpg
# cats_dogs/train/cats/cat.897.jpg
# cats_dogs/validation/cats/cat.1185.jpg
# cats_dogs/train/cats/cat.448.jpg
# cats_dogs/train/cats/cat.881.jpg
# cats_dogs/train/dogs/dog.734.jpg
# cats_dogs/train/cats/cat.978.jpg
# cats_dogs/train/dogs/dog.925.jpg
# cats_dogs/train/cats/cat.917.jpg
# cats_dogs/train/cats/cat.820.jpg
# cats_dogs/train/cats/cat.690.jpg
# cats_dogs/train/dogs/dog.795.jpg
# cats_dogs/test/test/242.jpg
# cats_dogs/validation/dogs/dog.1031.jpg
# cats_dogs/train/dogs/dog.346.jpg
# cats_dogs/train/cats/cat.241.jpg
# cats_dogs/train/cats/cat.432.jpg
# cats_dogs/train/dogs/dog.537.jpg
# cats_dogs/validation/dogs/dog.1319.jpg
# cats_dogs/validation/dogs/dog.1092.jpg
# cats_dogs/validation/cats/cat.1266.jpg
# cats_dogs/train/cats/cat.962.jpg
# cats_dogs/train/cats/cat.493.jpg
# cats_dogs/train/dogs/dog.598.jpg
# cats_dogs/validation/cats/cat.1008.jpg
# cats_dogs/test/test/24.jpg
# cats_dogs/train/dogs/dog.149.jpg
# cats_dogs/train/cats/cat.901.jpg
# cats_dogs/train/dogs/dog.8.jpg
# cats_dogs/train/dogs/dog.330.jpg
# cats_dogs/validation/cats/cat.1069.jpg
# cats_dogs/test/test/85.jpg
# cats_dogs/train/dogs/dog.521.jpg
# cats_dogs/validation/dogs/dog.1303.jpg
# cats_dogs/train/dogs/dog.618.jpg
# cats_dogs/train/dogs/dog.391.jpg
# cats_dogs/train/dogs/dog.133.jpg
# cats_dogs/train/dogs/dog.809.jpg
# cats_dogs/train/cats/cat.704.jpg
# cats_dogs/train/dogs/dog.582.jpg
# cats_dogs/validation/dogs/dog.1364.jpg
# cats_dogs/train/dogs/dog.679.jpg
# cats_dogs/test/test/126.jpg
# cats_dogs/train/cats/cat.574.jpg
# cats_dogs/train/cats/cat.316.jpg
# cats_dogs/train/cats/cat.765.jpg
# cats_dogs/validation/dogs/dog.1106.jpg
# cats_dogs/validation/cats/cat.1053.jpg
# cats_dogs/test/test/187.jpg
# cats_dogs/train/dogs/dog.194.jpg
# cats_dogs/train/dogs/dog.602.jpg
# cats_dogs/validation/cats/cat.1244.jpg
# cats_dogs/train/cats/cat.507.jpg
# cats_dogs/validation/dogs/dog.1167.jpg
# cats_dogs/train/cats/cat.377.jpg
# cats_dogs/train/dogs/dog.663.jpg
# cats_dogs/test/test/110.jpg
# cats_dogs/train/dogs/dog.854.jpg
# cats_dogs/train/cats/cat.119.jpg
# cats_dogs/train/dogs/dog.405.jpg
# cats_dogs/train/cats/cat.300.jpg
# cats_dogs/test/test/171.jpg
# cats_dogs/train/dogs/dog.46.jpg
# cats_dogs/validation/dogs/dog.1151.jpg
# cats_dogs/validation/cats/cat.1325.jpg
# cats_dogs/train/dogs/dog.466.jpg
# cats_dogs/validation/dogs/dog.1248.jpg
# cats_dogs/train/cats/cat.361.jpg
# cats_dogs/train/dogs/dog.208.jpg
# cats_dogs/validation/cats/cat.1386.jpg
# cats_dogs/train/cats/cat.649.jpg
# cats_dogs/train/cats/cat.103.jpg
# cats_dogs/train/cats/cat.66.jpg
# cats_dogs/validation/cats/cat.1128.jpg
# cats_dogs/train/dogs/dog.269.jpg
# cats_dogs/train/cats/cat.164.jpg
# cats_dogs/train/dogs/dog.30.jpg
# cats_dogs/train/dogs/dog.996.jpg
# cats_dogs/train/dogs/dog.450.jpg
# cats_dogs/validation/dogs/dog.1232.jpg
# cats_dogs/train/cats/cat.824.jpg
# cats_dogs/validation/cats/cat.1189.jpg
# cats_dogs/train/cats/cat.633.jpg
# cats_dogs/train/dogs/dog.738.jpg
# cats_dogs/validation/cats/cat.1370.jpg
# cats_dogs/train/dogs/dog.91.jpg
# cats_dogs/validation/dogs/dog.1293.jpg
# cats_dogs/train/dogs/dog.929.jpg
# cats_dogs/train/cats/cat.50.jpg
# cats_dogs/train/dogs/dog.253.jpg
# cats_dogs/train/dogs/dog.799.jpg
# cats_dogs/validation/cats/cat.1112.jpg
# cats_dogs/test/test/246.jpg
# cats_dogs/validation/dogs/dog.1035.jpg
# cats_dogs/train/dogs/dog.980.jpg
# cats_dogs/train/cats/cat.245.jpg
# cats_dogs/train/cats/cat.885.jpg
# cats_dogs/validation/cats/cat.1173.jpg
# cats_dogs/train/cats/cat.436.jpg
# cats_dogs/validation/dogs/dog.1096.jpg
# cats_dogs/train/dogs/dog.722.jpg
# cats_dogs/train/cats/cat.905.jpg
# cats_dogs/train/dogs/dog.913.jpg
# cats_dogs/train/cats/cat.497.jpg
# cats_dogs/test/test/28.jpg
# cats_dogs/train/cats/cat.420.jpg
# cats_dogs/train/dogs/dog.783.jpg
# cats_dogs/test/test/230.jpg
# cats_dogs/train/dogs/dog.334.jpg
# cats_dogs/validation/dogs/dog.1080.jpg
# cats_dogs/train/cats/cat.966.jpg
# cats_dogs/test/test/89.jpg
# cats_dogs/train/dogs/dog.525.jpg
# cats_dogs/validation/dogs/dog.1307.jpg
# cats_dogs/test/test/291.jpg
# cats_dogs/train/dogs/dog.1000.jpg
# cats_dogs/train/dogs/dog.395.jpg
# cats_dogs/train/cats/cat.708.jpg
# cats_dogs/train/cats/cat.290.jpg
# cats_dogs/train/cats/cat.481.jpg
# cats_dogs/train/dogs/dog.586.jpg
# cats_dogs/validation/dogs/dog.1368.jpg
# cats_dogs/test/test/12.jpg
# cats_dogs/train/dogs/dog.137.jpg
# cats_dogs/train/cats/cat.578.jpg
# cats_dogs/train/cats/cat.769.jpg
# cats_dogs/test/test/73.jpg
# cats_dogs/validation/cats/cat.1057.jpg
# cats_dogs/train/dogs/dog.198.jpg
# cats_dogs/train/cats/cat.950.jpg
# cats_dogs/train/dogs/dog.606.jpg
# cats_dogs/validation/cats/cat.1248.jpg
# cats_dogs/test/test/114.jpg
# cats_dogs/train/dogs/dog.570.jpg
# cats_dogs/validation/dogs/dog.1352.jpg
# cats_dogs/train/dogs/dog.667.jpg
# cats_dogs/train/dogs/dog.121.jpg
# cats_dogs/train/cats/cat.562.jpg
# cats_dogs/train/cats/cat.304.jpg
# cats_dogs/train/dogs/dog.858.jpg
# cats_dogs/train/cats/cat.753.jpg
# cats_dogs/train/dogs/dog.182.jpg
# cats_dogs/train/dogs/dog.409.jpg
# cats_dogs/validation/cats/cat.1041.jpg
# cats_dogs/test/test/175.jpg
# cats_dogs/validation/cats/cat.1232.jpg
# cats_dogs/validation/dogs/dog.1155.jpg
# cats_dogs/validation/cats/cat.1329.jpg
# cats_dogs/train/cats/cat.365.jpg
# cats_dogs/train/dogs/dog.651.jpg
# cats_dogs/train/dogs/dog.842.jpg
# cats_dogs/train/cats/cat.107.jpg
# cats_dogs/train/cats/cat.889.jpg
# cats_dogs/train/cats/cat.168.jpg
# cats_dogs/validation/dogs/dog.1236.jpg
# cats_dogs/validation/cats/cat.1313.jpg
# cats_dogs/train/dogs/dog.454.jpg
# cats_dogs/train/dogs/dog.34.jpg
# cats_dogs/train/cats/cat.682.jpg

# %%
# 1.13 Check folders under 'tanuja'
#      Folder 'cats_dogs' should exist:

! ls /root/tanuja/
print("====")

! ls /root/tanuja/cats_dogs
print("====")

! ls /root/tanuja/cats_dogs/train
print("====")

# ! ls /root/tanuja/cats_dogs/train/cats
# Out:
# cats_dogs
# ====
# test  train  validation
# ====
# cats  dogs
# ====

# %% [markdown]
# ## Constants

# %%
#%%                            B. Define constants

# 2. Our constants
# 2.1 Dimensions to which our images will be adjusted
img_width, img_height = 150, 150

# 2.2 Data folder containing all training images, maybe in folders: cats and dogs
#train_data_dir = '/home/ashok/Images/cats_dogs/train'
#train_data_dir ="C:\\Users\\ashok\\Desktop\\chmod\\2. data_augmentation\\cats_dogs\\train"
train_data_dir = '/root/tanuja/cats_dogs/train'
test_data_dir =  '/root/tanuja/cats_dogs/test'

# 2.3 What is the total number of training images
#      that should be generated (not what are available)
nb_train_samples = 2000   # Actual: 1000 + 1000 (more) =    2000

# 2.4 Data folder containing all validation images

#validation_data_dir = '/home/ashok/Images/cats_dogs/validation'
#validation_data_dir = "C:\\Users\\ashok\\Desktop\\chmod\\2. data_augmentation\\cats_dogs\\validation"
validation_data_dir = '/root/tanuja/cats_dogs/validation'

# 2.5 What is the total no of validation samples that should
#     be generated?
nb_validation_samples = 800   # Actual: 400 + 400 (more) =  800

# Some hyperparameters

# 2.6 Batch size to train at one go:
batch_size = 32             # No of batches = 4000/125 = 32
                            # So per epoch we have 32 batches

# 2.7 How many epochs of training?
epochs = 8                  # For lack of time, let us make it just 5.

# 2.8 No of test samples
test_generator_samples = 300

# 2.9 For test data, what should be batch size
test_batch_size = 16    # This is different from training batch size

# %%
# 3. About keras backend
# 3.1 Can get backend configuration values, as:
K.image_data_format()          # Read .keras conf file to findout
K.backend()

# 3.2 What is our backend and input_shape? Decide data shape as per that.
#     Depth goes last in TensorFlow back-end, first in Theano
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:                                         # So, Tensorflow!
    input_shape = (img_width, img_height, 3)
# Out:
# 'channels_last'
# 'tensorflow'

# %%
model = Sequential()
# 4.1 Add Input layer
model.add(Input(shape = (150,150,3)))
# 4.2 Add Conv2D layer
model.add(Conv2D(
               filters=32,                # For every filter there is set of weights
                                          # For each filter, one bias. So total bias = 32
               kernel_size=(3, 3),        # For each filter there are 3*3=9 kernel_weights
               strides = (1,1),           # So output shape will be 148 X 148 (W-F+1).
                                          # Default strides is 1 only
               #input_shape=input_shape,   # (150,150,3)
               use_bias=True,             # Default value is True
               padding='valid',           # 'valid' => No padding. This is default.
               name="Ist_conv_layer"
               )
         )
 
# 4.4 For each neuron in the convolved network,
#     assign an activation function
#     What is relu? See https://machinelearningmastery.com/rectified-linear-activation-function-for-deep-learning-neural-networks/
 
model.add(Activation('relu'))           # max {0,x}
 
# 4.6 pool_size:  max pooling window size: (2,2)
#     Default stride for pool-layer is same as pool_size
#     Here: 2 across and 2 down ie (2,2)
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D
 
model.add(MaxPool2D(pool_size=(2, 2)))
 
# 4.7
model.summary()
# 4.8 Input shape is inferred. Default strides is 1.
#     Note: Activation is specified here only
#     input_shape from top = 74 X 74 X 32
 
model.add(Conv2D(32,
                (3, 3),
                activation = 'relu',
                name = "IInd_con_layer"))
 
# 4.9 So how many parameters now?
#     Total weights = (kernel_weights) * (filters_from_earlier_conv) * (filters)  + ToalNoBias
model.summary()
# model.add(Activation('relu'))
 
# 4.10 Add another pooling layer:
 
model.add(MaxPool2D(pool_size=(2, 2)))
 
# 4.11 Summary?
model.summary()
# 4.12 Add another conv layer but with 64 filters
#      Total weights = (kernel_weights) * (filters_from_earlier_conv) * (filters)  + ToalNoBias
 
model.add(Conv2D(64, (3, 3), name = "IIIrd_conv_layer"))
 
# 4.13
model.summary()
# 4.14
model.add(Activation('relu'))
 
# 4.15
model.add(MaxPool2D(pool_size=(2, 2)))
 
# 4.16 Flattens the input. Does not affect the batch size.
#      It merely flattens the earlier layer without adding any weight
#     See summary() next
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten
 
model.add(Flatten(name = "FlattenedLayer"))
 
# 4.17
model.summary()
# 4.18 Dense layer having 64 units
#      dimensionality of the output space.
#      Total weights = hidden_neurons * input_size + bias_foreach_hidden_neurons
#      64 * 18496 + 64
#      Most number of weights come from this layer
#      https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense
 
model.add(Dense(64))
 
# 4.19
model.summary()
# 4.20
model.add(Activation('relu'))
 
# Dropout
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
model.add(Dropout(0.5))
 
# 4.21
model.summary()

 
# 4.22 Dense layer having 1 unit
#      dimensionality of the output space.
#      Weights = No of input neurons + bias (64+1)
model.add(Dense(1))
 
# 4.23
model.summary()
 
# 4.24
model.add(Activation('sigmoid'))    # tanh vs sigmoid? See Stackoverflow
 
# 4.25 Compile model
model.compile(
              loss='binary_crossentropy',  # Metrics to be adopted by convergence-routine
              optimizer='rmsprop',         # Strategy for convergence?
              metrics=['accuracy'])        # Metrics, I am interested in
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
# =================================================================
# Total params: 10,144
# Trainable params: 10,144
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
# =================================================================
# Total params: 10,144
# Trainable params: 10,144
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
# =================================================================
# Total params: 28,640
# Trainable params: 28,640
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_1 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
# =================================================================
# Total params: 28,640
# Trainable params: 28,640
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_1 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
# =================================================================
# Total params: 1,212,448
# Trainable params: 1,212,448
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_1 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
# =================================================================
# Total params: 1,212,448
# Trainable params: 1,212,448
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_1 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model design (Feature Engineering)

# %%
# 4. Create convnet model
#    con->relu->pool->con->relu->pool->con->relu->pool->flatten->fc->fc

#     Call model constructor and then pass on a list of layers
#     https://www.tensorflow.org/api_docs/python/tf/keras/Sequential

model = Sequential()

# %%
# 4.1 Add Input layer
model.add(Input(shape =(150,150,3) ))
# 4.2 Add Conv2D layer
model.add(Conv2D(
	             filters=32,                # For every filter there is set of weights
	                                        # For each filter, one bias. So total bias = 32
	             kernel_size=(3, 3),        # For each filter there are 3*3=9 kernel_weights
	             strides = (1,1),           # So output shape will be 148 X 148 (W-F+1).
	                                        # Default strides is 1 only
	             #input_shape=input_shape,   # (150,150,3)
	             use_bias=True,             # Default value is True
	             padding='valid',           # 'valid' => No padding. This is default.
	             name="Ist_conv_layer"
	             )
         )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-d038310b1479> in <module>
#       2 model.add(Input(shape =(150,150,3) ))
#       3 # 4.2 Add Conv2D layer
# ----> 4 model.add(Conv2D(
#       5                      filters=32,                # For every filter there is set of weights
#       6                                                 # For each filter, one bias. So total bias = 32
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     585     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586     try:
# --> 587       result = method(self, *args, **kwargs)
#     588     finally:
#     589       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py in add(self, layer)
#     181     tf_utils.assert_no_legacy_layers([layer])
#     182     if not self._is_layer_name_unique(layer):
# --> 183       raise ValueError(
#     184           'All layers added to a Sequential model '
#     185           f'should have unique names. Name "{layer.name}" is already the name '
#
# ValueError: All layers added to a Sequential model should have unique names. Name "Ist_conv_layer" is already the name of a layer in this model. Update the `name` argument to pass a unique name.

# %%
# 4.3 So what have we done? Can you explain?
#     Total weights = (kernel_weights) * RGB_channel * (filters)  + ToalNoBias
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.4 For each neuron in the convolved network,
#     assign an activation function
#     What is relu? See https://machinelearningmastery.com/rectified-linear-activation-function-for-deep-learning-neural-networks/

model.add(Activation('relu'))           # max {0,x}

# 4.5
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.6 pool_size:  max pooling window size: (2,2)
#     Default stride for pool-layer is same as pool_size
#     Here: 2 across and 2 down ie (2,2)
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D

model.add(MaxPool2D(pool_size=(2, 2)))

# 4.7
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.8 Input shape is inferred. Default strides is 1.
#     Note: Activation is specified here only
#     input_shape from top = 74 X 74 X 32

model.add(Conv2D(32,
                (3, 3),
                activation = 'relu',
                name = "IInd_con_layer"))

# 4.9 So how many parameters now?
#     Total weights = (kernel_weights) * (filters_from_earlier_conv) * (filters)  + ToalNoBias
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
# =================================================================
# Total params: 10,144
# Trainable params: 10,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.add(Activation('relu'))

# 4.10 Add another pooling layer:

model.add(MaxPool2D(pool_size=(2, 2)))

# 4.11 Summary?
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
# =================================================================
# Total params: 10,144
# Trainable params: 10,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.12 Add another conv layer but with 64 filters
#      Total weights = (kernel_weights) * (filters_from_earlier_conv) * (filters)  + ToalNoBias

model.add(Conv2D(64, (3, 3), name = "IIIrd_conv_layer"))

# 4.13
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
# =================================================================
# Total params: 28,640
# Trainable params: 28,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.14
model.add(Activation('relu'))

# 4.15
model.add(MaxPool2D(pool_size=(2, 2)))

# 4.16 Flattens the input. Does not affect the batch size.
#      It merely flattens the earlier layer without adding any weight
#     See summary() next
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten

model.add(Flatten(name = "FlattenedLayer"))

# 4.17
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_5 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
# =================================================================
# Total params: 28,640
# Trainable params: 28,640
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Classification layer

# %%
# 4.18 Dense layer having 64 units
#      dimensionality of the output space.
#      Total weights = hidden_neurons * input_size + bias_foreach_hidden_neurons
#      64 * 18496 + 64
#      Most number of weights come from this layer
#      https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense

model.add(Dense(64))

# 4.19
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_5 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
#  dense_11 (Dense)            (None, 64)                1183808
#
# =================================================================
# Total params: 1,212,448
# Trainable params: 1,212,448
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.20
model.add(Activation('relu'))

# Dropout
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
model.add(Dropout(0.5))

# 4.21
model.summary()


# 4.22 Dense layer having 1 unit
#      dimensionality of the output space.
#      Weights = No of input neurons + bias (64+1)
model.add(Dense(1))

# 4.23
model.summary()

# 4.24
model.add(Activation('sigmoid'))    # tanh vs sigmoid? See Stackoverflow
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_5 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
#  dense_11 (Dense)            (None, 64)                1183808
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
# =================================================================
# Total params: 1,212,448
# Trainable params: 1,212,448
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Ist_conv_layer (Conv2D)     (None, 148, 148, 32)      896
#
#  activation_4 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  IInd_con_layer (Conv2D)     (None, 72, 72, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  IIIrd_conv_layer (Conv2D)   (None, 34, 34, 64)        18496
#
#  activation_5 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  FlattenedLayer (Flatten)    (None, 18496)             0
#
#  dense_11 (Dense)            (None, 64)                1183808
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compilation

# %%
# 4.25 Compile model
model.compile(
              loss='binary_crossentropy',  # Metrics to be adopted by convergence-routine
              optimizer='rmsprop',         # Strategy for convergence?
              metrics=['accuracy'])        # Metrics, I am interested in

# %% [markdown]
# ## Data Generators

# %%
#%%                            D. Create Data generators


## 5. Image augmentation
# 5.1 Define a preprocessing function
def preprocess(img):
	# Histogram equalization
	# WITHOUT IT RESULTS ARE BETTER
	# http://scikit-image.org/docs/dev/auto_examples/color_exposure/plot_equalize.html
    # img_eq = exposure.equalize_hist(img)
    # Do something more with image
    return img

# %%
# 5.2 Config1: Augmentation configuration for training samples
#     Instantiate ImageDataGenerator object with requisite configuration
#     https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

tr_dtgen = ImageDataGenerator(
                              rescale=1. / 255,      # Normalize colour intensities in 0-1 range
                              shear_range=0.2,       # Shear varies from 0-0.2
                              zoom_range=0.2,
                              horizontal_flip=True,
                              preprocessing_function=preprocess
                              )

# %%
# 5.3 Config2: Create iterator from 'train_datagen'.
#     We use flow() or flow_from_directory() methods to further
#     configure and return an iterator object.
#     See at the end of code: Differences between flow()
#     and flow_from_directory
#     Pl see: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator#flow_from_directory

train_generator = tr_dtgen.flow_from_directory(
                                               train_data_dir,       # Data folder of cats & dogs
                                               target_size=(img_width, img_height),  # Resize images
                                               batch_size=batch_size,  # Return images in batches
                                               class_mode='binary'   # Output labels will be 1D binary labels
                                                                     # [[1],[0],[0],[1]]
                                                                     # If 'categorical' output labels will be
                                                                     # 2D OneHotEncoded: [[1,0],[0,1],[0,1],[1,0]]
                                                                     # If 'binary' use 'sigmoid' at output
                                                                     # If 'categorical' use softmax at output

                                                )
# Out:
# Found 2000 images belonging to 2 classes.

# %%
# 5.4 Augmentation configuration we will use
#     for validation. Only rescaling of pixels

val_dtgen = ImageDataGenerator(rescale=1. / 255)

# %%
# 5.4.1 validation data
validation_generator = val_dtgen.flow_from_directory(
                                                     validation_data_dir,
                                                     target_size=(img_width, img_height),   # Resize images
                                                     batch_size=batch_size,    # batch size to augment at a time
                                                     class_mode='binary'  # Return 1D array of class labels
                                                     )
# Out:
# Found 800 images belonging to 2 classes.

# %% [markdown]
# ## Model fitting

# %%
#%%                           E. Fit model & save CNN network weights


## 6. Model fitting

# 6.1 Manual process of fitting. Get infinite images
#     Can experiment with infinite images. We will
#     generate upto 3200 images
#     https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit

start = time.time()   # 6 minutes
for e in range(epochs):
    print('Epoch', e)
    batches = 0
    # 6.1.1
    for x_batch, y_batch in train_generator:

        # 6.1.2 Earlier learnt weights are preserved
          # between batches
        model.fit(x_batch, y_batch)
        batches += 1
        print ("Epoch: {0} , Batches: {1}".format(e,batches))
        # 6.1.3
        if batches > 200:    # 200 * 16 = 3200 images
            # we need to break the loop by hand because
# Epoch: 3 , Batches: 196
# 1/1 [==============================] - 1s 537ms/step - loss: 0.4671 - accuracy: 0.8750
# Epoch: 3 , Batches: 197
# 1/1 [==============================] - 1s 536ms/step - loss: 0.4978 - accuracy: 0.7500
# Epoch: 3 , Batches: 198
# 1/1 [==============================] - 1s 533ms/step - loss: 0.5964 - accuracy: 0.6875
# Epoch: 3 , Batches: 199
# 1/1 [==============================] - 1s 519ms/step - loss: 0.7363 - accuracy: 0.5938
# Epoch: 3 , Batches: 200
# 1/1 [==============================] - 1s 529ms/step - loss: 0.5005 - accuracy: 0.7500
# Epoch: 3 , Batches: 201
# Epoch 4
# 1/1 [==============================] - 1s 528ms/step - loss: 0.3834 - accuracy: 0.8125
# Epoch: 4 , Batches: 1
# 1/1 [==============================] - 1s 526ms/step - loss: 0.5109 - accuracy: 0.8125
# Epoch: 4 , Batches: 2
# 1/1 [==============================] - 1s 534ms/step - loss: 0.3815 - accuracy: 0.8438
# Epoch: 4 , Batches: 3
# 1/1 [==============================] - 1s 528ms/step - loss: 0.6872 - accuracy: 0.6562
# Epoch: 4 , Batches: 4
# 1/1 [==============================] - 1s 520ms/step - loss: 0.5488 - accuracy: 0.7188
# Epoch: 4 , Batches: 5
# 1/1 [==============================] - 1s 536ms/step - loss: 0.3353 - accuracy: 0.8750
# Epoch: 4 , Batches: 6
# 1/1 [==============================] - 1s 544ms/step - loss: 0.4577 - accuracy: 0.8125
# Epoch: 4 , Batches: 7
# 1/1 [==============================] - 1s 528ms/step - loss: 0.3870 - accuracy: 0.8438
# Epoch: 4 , Batches: 8
# 1/1 [==============================] - 1s 529ms/step - loss: 0.4453 - accuracy: 0.7812
# Epoch: 4 , Batches: 9
# 1/1 [==============================] - 1s 531ms/step - loss: 0.6176 - accuracy: 0.7188
# Epoch: 4 , Batches: 10
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-24-1d4ca6d6d675>", line 20, in <module>
#     model.fit(x_batch, y_batch)
#   File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1396, in fit
#     for epoch, iterator in data_handler.enumerate_epochs():
#   File "/usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py", line 1193, in enumerate_epochs
#     data_iterator = iter(self._dataset)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 494, in __iter__
#     return iterator_ops.OwnedIterator(self)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 696, in __init__
#     self._create_iterator(dataset)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 721, in _create_iterator
#     gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 3409, in make_iterator
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/usr/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/usr/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/usr/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
# 6.2 fit_generator() directly pulls data from iterators
#     But number of images cannot exceed those available
#     Ref: https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator

start = time.time()
history = model.fit_generator(
                              # First argument is always data generator
                              generator = train_generator,          
                              # How many batches per epoch?
                               # Can be any number as generator loops indefinitely 
                              steps_per_epoch=nb_train_samples // batch_size, 
                              # No of epochs                                               
                              epochs=epochs,  
                              # Get validation data from validation generator                      
                              validation_data=validation_generator, 
                              verbose = 1,                          
                              validation_steps=nb_validation_samples // batch_size
                              )

end = time.time()
(end - start)/60
# Out:
# <ipython-input-23-9a4a2fbfc837>:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/8
# 62/62 [==============================] - 50s 796ms/step - loss: 0.7282 - accuracy: 0.5163 - val_loss: 0.6867 - val_accuracy: 0.6475
# Epoch 2/8
# 62/62 [==============================] - 46s 740ms/step - loss: 0.6868 - accuracy: 0.5620 - val_loss: 0.6627 - val_accuracy: 0.5575
# Epoch 3/8
# 62/62 [==============================] - 46s 744ms/step - loss: 0.6485 - accuracy: 0.6179 - val_loss: 0.6162 - val_accuracy: 0.6450
# Epoch 4/8
# 62/62 [==============================] - 46s 739ms/step - loss: 0.6209 - accuracy: 0.6717 - val_loss: 0.9092 - val_accuracy: 0.5612
# Epoch 5/8
# 62/62 [==============================] - 46s 743ms/step - loss: 0.6058 - accuracy: 0.6865 - val_loss: 0.5667 - val_accuracy: 0.6837
# Epoch 6/8
# 62/62 [==============================] - 46s 738ms/step - loss: 0.5741 - accuracy: 0.7027 - val_loss: 0.6392 - val_accuracy: 0.6125
# Epoch 7/8
# 62/62 [==============================] - 46s 737ms/step - loss: 0.5657 - accuracy: 0.7022 - val_loss: 0.5520 - val_accuracy: 0.7088
# Epoch 8/8
# 62/62 [==============================] - 46s 740ms/step - loss: 0.5519 - accuracy: 0.7312 - val_loss: 0.5496 - val_accuracy: 0.7163
# 9.201156969865163

# %% [markdown]
# ## Model evaluation & Predictions

# %%
# 7.0 Model evaluation

# 7.1 Using generator
#     https://www.tensorflow.org/api_docs/python/tf/keras/Model#evaluate
result = model.evaluate(
                        validation_generator,
                        verbose = 1,
                        steps = 4        # How many batches
                        )


# 7.1.1
result     # ['loss', 'accuracy']
# Out:
# 4/4 [==============================] - 1s 196ms/step - loss: 0.5628 - accuracy: 0.7188
# [0.562846302986145, 0.71875]

# %%
# 8.0 Make predictions

# 8.1 Using generator
#     https://www.tensorflow.org/api_docs/python/tf/keras/Model#predict
pred = model.predict(validation_generator, steps = 2)

# 8.1.1
pred[:5]
# Out:
# 2/2 [==============================] - 1s 228ms/step
# array([[0.5561028 ],
#        [0.5975166 ],
#        [0.33763444],
#        [0.10167088],
#        [0.6253285 ]], dtype=float32)

# %%
# 8.2 Manually
pred = []
steps = 0
start = time.time()
# 8.2.1
for x_batch, y_batch in validation_generator:
        # 8.2.2
        pred.append(model.predict(x_batch))
        steps += 1
        # 8.2.3
        if steps >= 2:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break

end = time.time()
(end - start)/60

# 8.2.4
pred
# Out:
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 180ms/step
# 0.013869043191274006
# [array([[0.4702513 ],
#         [0.0909461 ],
#         [0.99885386],
#         [0.96906906],
#         [0.21454094],
#         [0.37945795],
#         [0.47147793],
#         [0.6424098 ],
#         [0.50082314],
#         [0.22036807],
#         [0.8733537 ],
#         [0.2424786 ],
#         [0.10604241],
#         [0.7583055 ],
#         [0.92566496],
#         [0.49277574],
#         [0.43903232],
#         [0.2546703 ],
#         [0.9998838 ],
#         [0.6595174 ],
#         [0.38234395],
#         [0.8118629 ],
#         [0.14603443],
#         [0.33750555],
#         [0.3771677 ],
#         [0.45914847],
#         [0.66589814],
#         [0.42208976],
#         [0.76711917],
#         [0.4821492 ],
#         [0.5056681 ],
#         [0.8092444 ]], dtype=float32), array([[0.27407366],
#         [0.08819962],
#         [0.32947835],
#         [0.39511222],
#         [0.5384751 ],
#         [0.51508206],
#         [0.7917488 ],
#         [0.3181147 ],
#         [0.26569214],
#         [0.7957358 ],
#         [0.8537457 ],
#         [0.8322411 ],
#         [0.6662062 ],
#         [0.02703738],
#         [0.504552  ],
#         [0.50383997],
#         [0.31660277],
#         [0.22318211],
#         [0.12283824],
#         [0.48735127],
#         [0.7223966 ],
#         [0.7220978 ],
#         [0.7931512 ],
#         [0.82865673],
#         [0.5658946 ],
#         [0.6953274 ],
#         [0.41030064],
#         [0.3560316 ],
#         [0.7699596 ],
#         [0.2327122 ],
#         [0.4652098 ],
#         [0.6529379 ]], dtype=float32)]

# %%
######### End of class

# %% [markdown]
# ## Rest

# %%
# 9.0 Augmentation configuration we will use
#     for test-data. Only rescaling of pixels

test_dtgen = ImageDataGenerator(rescale=1. / 255)

# 9.0.1 Test data

test_generator = test_dtgen.flow_from_directory(
                                                test_data_dir,
                                                # Resize images
                                                target_size=(img_width, img_height),   
                                                # batch size to augment at a time
                                                batch_size=batch_size,
                                                # Return 1D array of class labels    
                                                class_mode='binary'  
                                                )
# Out:
# Found 300 images belonging to 1 classes.

# %%
# 9.0.2 Get iterator 
#       and a batch of (images, image_labels)
im = test_generator    # Get iterator
images = next(im)      # Get images
images[0].shape
# Out:
# (32, 150, 150, 3)

# %%
# 9.1 Make predictions
results = model.predict(images[0])

# 9.2 Plot the images and check with
#     results
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
plt.figure(figsize= (10,10))
for i in range(results.shape[0]):
    plt.subplot(4,4,i+1)
    _=imshow(images[0][i]) ;

plt.show() ;
# 9.3 Predicted labels
print(results)         # Probability values
                       # > 0.5 is Dog
# Out:
# 1/1 [==============================] - 0s 153ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-c493b95ead94> in <module>
#       8 plt.figure(figsize= (10,10))
#       9 for i in range(results.shape[0]):
# ---> 10     plt.subplot(4,4,i+1)
#      11     _=imshow(images[0][i]) ;
#      12
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      63             else:
#      64                 if num < 1 or num > rows*cols:
# ---> 65                     raise ValueError(
#      66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#
# ValueError: num must be 1 <= num <= 16, not 17

# %% [markdown]
# ## Model saving

# %%
## 10. Model saving
# 10.1 Install h5py using Anaconda
# 10.2 Save CNN model weights to a file
#     The h5py package is a Pythonic interface to HDF5 binary data format.
#     It lets you store huge amounts of numerical data, and easily manipulate
#     that data from NumPy. For example, you can slice into multi-terabyte
#     datasets stored on disk, as if they were real NumPy arrays.
#     Thousands of datasets can be stored in a single file, categorized and
#     tagged however you want.

# 10.3 Delete earlier model folder if it exists
# os.system('rm -rf  /root/tanuja/model')
! rm -rf  /root/tanuja/model

# 10.4 Create a fresh folder:
# os.mkdir("/home/tanuja/useless")
! mkdir -p /root/tanuja/model

# 10.5 Check for 'model' folder
! ls -la /root/tanuja
# Out:
# total 20
# drwxr-xr-x 4 root root 4096 Dec 28 10:35 .
# drwx------ 1 root root 4096 Dec 28 10:15 ..
# drwxrwxr-x 5 1000 1000 4096 Feb  7  2018 cats_dogs
# drwxr-xr-x 2 root root 4096 Dec 28 10:35 model

# %%
# 11.0 Save model weights
model.save_weights("/root/tanuja/model/model_cats_dogs.h5")

# 11.1 Check the model-file and its size
! ls  -la /root/tanuja/model
# Out:
# total 4776
# drwxr-xr-x 2 root root    4096 Dec 28 10:35 .
# drwxr-xr-x 4 root root    4096 Dec 28 10:35 ..
# -rw-r--r-- 1 root root 4879936 Dec 28 10:35 model_cats_dogs.h5

# %%
# 11.2 Copy saved file to your Google drive
! cp -r /root/tanuja/model/gdrive/MyDrive/Colab_data_files/cats_dogs

# 11.2.1 Check for file transfer to google drive
! ls /gdrive/MyDrive/Colab_data_files/cats_dogs/model
# Out:
# cp: missing destination file operand after '/root/tanuja/model/gdrive/MyDrive/Colab_data_files/cats_dogs'
# Try 'cp --help' for more information.
# ls: cannot access '/gdrive/MyDrive/Colab_data_files/cats_dogs/model': No such file or directory

# %%
# 11.3 Save your CNN model structure to 
#      a file in 'json' format: cnn_model.json
cnn_model = model.to_json()
cnn_model
# Out:
# '{"class_name": "Sequential", "config": {"name": "sequential", "layers": [{"class_name": "InputLayer", "config": {"batch_input_shape": [null, 150, 150, 3], "dtype": "float32", "sparse": false, "ragged": false, "name": "input_1"}}, {"class_name": "Conv2D", "config": {"name": "Ist_conv_layer", "trainable": true, "dtype": "float32", "filters": 32, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation", "trainable": true, "dtype": "float32", "activation": "relu"}}, {"class_name": "MaxPooling2D", "config": {"name": "max_pooling2d", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}}, {"class_name": "Conv2D", "config": {"name": "IInd_con_layer", "trainable": true, "dtype": "float32", "filters": 32, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "relu", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "MaxPooling2D", "config": {"name": "max_pooling2d_1", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}}, {"class_name": "Conv2D", "config": {"name": "IIIrd_conv_layer", "trainable": true, "dtype": "float32", "filters": 64, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation_1", "trainable": true, "dtype": "float32", "activation": "relu"}}, {"class_name": "MaxPooling2D", "config": {"name": "max_pooling2d_2", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}}, {"class_name": "Flatten", "config": {"name": "FlattenedLayer", "trainable": true, "dtype": "float32", "data_format": "channels_last"}}, {"class_name": "Dense", "config": {"name": "dense", "trainable": true, "dtype": "float32", "units": 64, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation_2", "trainable": true, "dtype": "float32", "activation": "relu"}}, {"class_name": "Dropout", "config": {"name": "dropout", "trainable": true, "dtype": "float32", "rate": 0.5, "noise_shape": null, "seed": null}}, {"class_name": "Dense", "config": {"name": "dense_1", "trainable": true, "dtype": "float32", "units": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kerne ...

# %%
# 11.4 Now save this json formatted data to a file on hard-disk
#     File name: cnn_model.json. File path: check with setwd()
# 11.4.1. Open/create file in write mode

#json_file = open("/home/tanuja/useless/cnn_model.json", "w")
#json_file = open("c:\\users\\tanuja\\useless\\cnn_model.json", "w")
json_file = open("/root/tanuja/model/cnn_model.json", "w")

# 11.4.2 Write to file
json_file.write("cnn_model")
# 11.4.3 Close file
json_file.close()

# 11.5 Check for saved file
! ls -la /root/tanuja/model
# Out:
# 9
# total 4780
# drwxr-xr-x 2 root root    4096 Dec 28 10:35 .
# drwxr-xr-x 4 root root    4096 Dec 28 10:35 ..
# -rw-r--r-- 1 root root       9 Dec 28 10:36 cnn_model.json
# -rw-r--r-- 1 root root 4879936 Dec 28 10:35 model_cats_dogs.h5

# %% [markdown]
# ## Loading model

# %%
#%%                          F. Load model and model weights


## 12. Later

# 12.1 Open saved model file in read only mode
#     Just
# os.chdir("C:\\Users\\ashokharnal")

#json_file = open('/home/tanuja/useless/cnn_model.json', 'r')
#json_file = open("c:\\users\\tanuja\\useless\\cnn_model.json", "r")
json_file = open('/root/tanuja/model/cnn_model.json', 'r')

loaded_model_json = json_file.read()
loaded_model_json            # Model structure in file: loded_model_json
json_file.close()

# 12.2 Create CNN model from the file: loaded_model_json
cnn_model = model_from_json(loaded_model_json)


# 12.3 load saved weights into new model
cnn_model.load_weights("/root/tanuja/model/model_cats_dogs.h5")
#cnn_model.load_weights("c:\\users\\tanuja\\useless\\first_try.h5")


# 12.4 Compile the model. Same way as was done earlier
cnn_model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])


#%%                         G. Make predictions on test data

# 13 Where is the directory which contains ANOTHER directory
#   containing your test images
#test_data_dir = validation_data_dir = 'E:/cats_and_dogs/test'


# 13.1 Augmentation configuration for test dataset.
#     Only rescaling as we did for validation data
test_datagen = ImageDataGenerator(rescale=1. / 255)


# 13.2 Create test data generator
test_generator = test_datagen.flow_from_directory(
        test_data_dir,                         # Which folder has test data
        target_size=(img_width, img_height),   # Resize images
        batch_size = test_batch_size,            # batch size to augment at a time
        class_mode=None)                       # Data has binary classes



# 14. Make predictions from loaded model. Takes few seconds.
start = time.time()
predictions = cnn_model.predict_generator(
        test_generator,
        steps= int(test_generator_samples/float(test_batch_size)), # all samples once
        verbose =1
        )
end  = time.time()
(end-start)/60

# 14.1 OR predictions directly from created model
start = time.time()
predictions1 = model.predict_generator(
        test_generator,
        steps=int(test_generator_samples/float(test_batch_size)), # all samples once
        verbose =1
        )

end  = time.time()
(end-start)/60


# 14.2 See arrays of predictions
#predictions
predictions[0:10]
# Out:
# 'cnn_model'
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-45-03bcf9a915d1> in <module>
#      17
#      18 # 12.2 Create CNN model from the file: loaded_model_json
# ---> 19 cnn_model = model_from_json(loaded_model_json)
#      20
#      21
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/model_config.py in model_from_json(json_string, custom_objects)
#     100   """
#     101   from keras.layers import deserialize_from_json  # pylint: disable=g-import-not-at-top
# --> 102   return deserialize_from_json(json_string, custom_objects=custom_objects)
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/serialization.py in deserialize_from_json(json_string, custom_objects)
#     220   """Instantiates a layer from a JSON string."""
#     221   populate_deserializable_objects()
# --> 222   config = json_utils.decode_and_deserialize(
#     223       json_string,
#     224       module_objects=LOCAL.ALL_OBJECTS,
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/json_utils.py in decode_and_deserialize(json_string, module_objects, custom_objects)
#      73                            custom_objects=None):
#      74   """Decodes the JSON and deserializes any Keras objects found in the dict."""
# ---> 75   return json.loads(json_string,
#      76                     object_hook=functools.partial(
#      77                         _decode_helper,
#
# /usr/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     368     if parse_constant is not None:
#     369         kw['parse_constant'] = parse_constant
# --> 370     return cls(**kw).decode(s)
#
# /usr/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Submissions on Kaggle

# %%
####--
#### Code to be corrected
####--
#%%                         H. Make submissions on Kaggle


# 15. Unfortunately Kaggle is not allowing submissions.
#     I have manually compiled a file looking at 300 images out of 12500
#     images in the test folder.
actual=pd.read_csv("E:/cats_and_dogs/actual_result300.csv", header = 0)
actual.head()

# 15.1 Add predictions column to this data frame
actual['new'] = predictions[0:300]

# 15. Evaluate accuracy
fpr, tpr, _ = metrics.roc_curve(actual['label'], actual['new'])

# 15.1 AUC
metrics.roc_auc_score(actual['label'], actual['new'])

# 15.2 ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange')
plt.show()

############ END ##############################################
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-1af82ee18bdb> in <module>
#       8 #     I have manually compiled a file looking at 300 images out of 12500
#       9 #     images in the test folder.
# ---> 10 actual=pd.read_csv("E:/cats_and_dogs/actual_result300.csv", header = 0)
#      11 actual.head()
#      12
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/cats_and_dogs/actual_result300.csv'
