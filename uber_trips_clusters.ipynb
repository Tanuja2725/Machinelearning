# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanuja2725/machinelearning/blob/main/uber_trips_clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#"""
Last amended: 6th Sep, 2022
My folder: D:\data\OneDrive\Documents\uber

           /home/ashok/Documents/4.clustering
           
DataSource:
             https://github.com/fivethirtyeight/uber-tlc-foil-response/tree/master/uber-trip-data   
             https://github.com/caroljmcdonald/spark-ml-kmeans-uber  
                   

Ref: knuggets 
    https://www.kdnuggets.com/2020/07/clustering-rideshare-data-uber.html
    Aurelion Book: https://github.com/ageron/handson-ml2/blob/master/09_unsupervised_learning.ipynb

Ref: Using pyspark
    https://github.com/mutukulasureshkumar/K-Means_Clustering_PySpark

Objectives: 
#           1. Use Uber data to perform clustering
               and advise Uber of possible locations to
               use as hub for taxis
            2. Process data in a manner done for
               out-of-core machine learning.
            3. Use MiniBatchKMeans()

"""
# Out:
#   File "<tokenize>", line 23
#     2. Process data in a manner done for
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ### Problem
# Uber Technologies Inc. is a peer-to-peer ride sharing platform. Uber's platform connects the drivers who can drive to a customer's location. Uber uses machine learning, for calculating pricing to finding the optimal positioning of cars to maximizing profits. We have used the public Uber trip dataset to discuss building a real-time example for analysis and monitoring of car GPS data.
#
# The Uber trip dataset contains data generated by Uber from New York City. The data is freely available on [FiveThirtyEight](https://data.fivethirtyeight.com/).

# %% [markdown]
# ### A. Software install & Call libraries

# %%
# 0.0 Let therebe display from multiple commands
#     from a jupyter cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 0.1 Should be 1.5
import yellowbrick
yellowbrick.__version__     # Should be: 1.5

# 0.2 Should be 0.12.1
import folium
folium.__version__          # Should be: 0.12.1.post1
# Out:
# '1.5'
# '0.12.1.post1'

# %%
# 0.3 IF not correct versions, 
#     install desied versions
#!pip install yellowbrick==1.3
#!pip install folium==0.12.1

# %%
# 1.0 Call libraries
# %reset -f
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# 1.1 Visualization
import matplotlib.pyplot as plt
# conda install -c conda-forge folium
import folium

# conda install -c districtdatalabs yellowbrick
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import silhouette_visualizer
# 1.2
import os,time

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %% [markdown]
# ### B. Mount gdrive

# %%
# 1.4 Connect to your google drive

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# 2.0 Read data. Set pathToFolder where file uber_raw_data_apr_sep2014.csv.zip
#     is placed


pathToFolder = "/gdrive/MyDrive/colab_data_ files/Uber/"

# %%
# 2.0.1 MAke out data folder working directory:

os.chdir(pathToFolder)

# %% [markdown]
# ### C. Read data

# %%
# 2.1 Read uber data:

#data = pd.read_csv(
  #                 pathToFolder + "uber_raw_data_apr_sep2014.csv.zip",
   #                names =["dtime","lat","long","base"]
    #               )

data = pd.read_csv(
                    "uber_raw_data_apr_sep2014.csv.zip",
    
                   names =["dtime","lat","long","base"]
                   )

# %%
# 2.1.1 Look at the data:

data.shape    # (4534327, 4) 45lakh rows
data.head()
data.dtypes
# Out:
# (4534327, 4)
#               dtime      lat     long    base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512
# dtime     object
# lat      float64
# long     float64
# base      object
# dtype: object

# %% [markdown]
# The dataset has 45 lakh observations and four columns. It has four attributes:
#
# > **Date/Time:** The date and time of the Uber pickup.<br>
# **Lat(Latitude)**: The latitude of the Uber pickup<br>
# **Lon(Longitude)**: The longitude of the Uber pickup.<br>
# **Base**: the TLC base company code affiliated with the Uber pickup. <br>

# %% [markdown]
# ### D. Store file to disk as memory-map

# %% [markdown]
# Create a memory-map to an array stored in a binary file on disk. Refer [here](https://numpy.org/doc/stable/reference/generated/numpy.memmap.html).<br>
# Memory-mapped files are used for accessing small segments of large files on disk, without reading the entire file into memory. NumPy’s memmap’s are array-like objects. This differs from Python’s mmap module, which uses file-like objects.
#
# Flush the memmap instance to write the changes to the file. Currently there is no API to *close* the underlying mmap. It is tricky to ensure the resource is actually closed, since it may be shared between different memmap instances.

# %%
# 2.2 We need only two columns
#     to perform clustering:

clus = data[["lat","long"]]

# 2.2.1 IF your RAM is large, take
#       ,say, first 10000 rows
clus = clus[:]     # clus = clus[:100000]

# %%
# 2.2.2 If a memmap file (.npy) already exists
#       delete it first:

! pwd
! rm -f *.npy
! ls -la
# Out:
# /gdrive/MyDrive/colab_data_ files/Uber
# total 30184
# -rw------- 1 root root 30815362 Sep  8 05:50 uber_raw_data_apr_sep2014.csv.zip
# -rw------- 1 root root    92650 Sep  8 06:12 uber_trips_clusters.ipynb

# %%
# 2.3 Create a memcap file
#     to store data of clus.shape
#     It is a zero-filled file

# https://numpy.org/doc/stable/reference/generated/numpy.memmap.html

clus_file = np.memmap('clus_mem.npy',
                      dtype='float32',
                      mode='w+',
                      shape=clus.shape      #45LAKH*2
                      )

# %%
# 2.3.1 Check if file created

#! ls -la
! ls -ltr
# Out:
# total 65609
# -rw------- 1 root root 30815362 Sep  8 05:50 uber_raw_data_apr_sep2014.csv.zip
# -rw------- 1 root root    92650 Sep  8 06:12 uber_trips_clusters.ipynb
# -rw------- 1 root root 36274616 Sep 21 09:39 clus_mem.npy

# %%
# 2.3.2 And what all this file contains:

clus_file[:5]
# Out:
# memmap([[ 40.769 , -73.9549],
#         [ 40.7267, -74.0345],
#         [ 40.7316, -73.9873],
#         [ 40.7588, -73.9776],
#         [ 40.7594, -73.9722]], dtype=float32)

# %%
# 2.4 Now fill this file with our data:

clus_file[:]= clus

# %%
# 2.4.1 Check again:

clus_file[:3]
# Out:
# memmap([[ 40.769 , -73.9549],
#         [ 40.7267, -74.0345],
#         [ 40.7316, -73.9873]], dtype=float32)

# %%
# 2.4.2 And check file:

! ls -la
# Out:
# total 65609
# -rw------- 1 root root 36274616 Sep 21 09:39 clus_mem.npy
# -rw------- 1 root root 30815362 Sep  8 05:50 uber_raw_data_apr_sep2014.csv.zip
# -rw------- 1 root root    92650 Sep  8 06:12 uber_trips_clusters.ipynb

# %%
# 2.4.3 Delete our files
#       in RAM:

del clus
del data

# 2.4.4 And flush memcap file from RAM:

clus_file.flush()

# %% [markdown]
# ### E. Read mammap file and process data

# %%
# 3.0 Open memmap file in read mode:
clus_read = np.memmap(
                      'clus_mem.npy',
                      dtype='float32',
                      mode='r',
                      shape=(4534327, 2)
                      )

# %%
# 3.1
clus_read.shape
print()
# 3.2
clus_read[:4]
# Out:
# (4534327, 2)
# memmap([[ 40.769 , -73.9549],
#         [ 40.7267, -74.0345],
#         [ 40.7316, -73.9873],
#         [ 40.7588, -73.9776]], dtype=float32)

# %%
# 3.3 Here is how we will shuffle data:

x = np.arange(clus_read.shape[0])
x[:4]
print("")
# 3.3.1 Shuffle 'x' in place
np.random.shuffle(x)
x[:4]
# Out:
# array([0, 1, 2, 3])
# array([2494364, 1810217, 1900407, 2389288])

# %%
# 3.4 Our shuffled set
#     of 1lakh rows

clus = clus_read[x[:100000]]
clus.shape
# Out:
# (100000, 2)

# %% [markdown]
# ###F. How many clusters?

# %%
# 4.0 What should be the number of clusters?
#     We will use data of size 1 lakh:

inertia = []
s_score = []
start = time.time()

# 4.1
for i in range(2,10):

    # 4.1.1 Pick random data from memmap
    x = np.arange(clus_read.shape[0])
    np.random.shuffle(x)
    clus = clus_read[x[:100000]]

    # 4.1.2 The model
    model = KMeans(
                    n_clusters = i,
                    max_iter = 500)
    model.fit(clus) 
    print("--")    
    print(model.n_iter_)
    print("--")
    # 4.1.3 Store inertia value
    inertia.append(model.inertia_)
    
    # 4.1.4 Calculate silhoutte score
    t=silhouette_score(clus, model.labels_, sample_size = 10000)
    s_score.append(t)
    print()

end = time.time()
(end-start)/60    # 7minutes
# Out:
# KMeans(max_iter=500, n_clusters=2)
# --
# 8
# --
# KMeans(max_iter=500, n_clusters=3)
# --
# 8
# --
# KMeans(max_iter=500, n_clusters=4)
# --
# 34
# --
# KMeans(max_iter=500, n_clusters=5)
# --
# 12
# --
# KMeans(max_iter=500, n_clusters=6)
# --
# 11
# --
# KMeans(max_iter=500, n_clusters=7)
# --
# 15
# --
# KMeans(max_iter=500)
# --
# 16
# --
# KMeans(max_iter=500, n_clusters=9)
# --
# 19
# --
# 0.3320446014404297

# %% [markdown]
# ### G.Scree plot and Silhoutte score

# %%
# 4.2 Values of inertia
inertia
# Out:
# [301.9729309082031,
#  236.0986328125,
#  187.03591918945312,
#  154.50732421875,
#  118.7967758178711,
#  100.60189819335938,
#  88.90348815917969,
#  77.91168212890625]

# %%
# 4.3 Elbow plot
plt.figure()
plt.plot(range(2,10),inertia)
plt.show()

# %% [markdown]
# From the above elbow plot, we can see that
# the sum of the squared distance of the
# observations from their closest cluster
# centroid keeps decreasing with an increase
# in the number of clusters. We can see that
# after K=6 there is a significant reduction.
# We can choose either 6 or 7 clusters, and for
# this application we have chosen 6.

# %%
# 4.4 Values of silhoutte score

s_score
# Out:
# [0.71043956,
#  0.37605932,
#  0.39884946,
#  0.4055456,
#  0.44757277,
#  0.44728446,
#  0.45713192,
#  0.41299713]

# %%
# 4.5 Silhoutte score plot:

plt.figure()
plt.plot(range(2,10),s_score)
plt.show()

# %% [markdown]
# ### H. Final model

# %% [markdown]
# We will use `MiniBatchKMeans`. It is much faster! However, its performance is often lower (higher inertia), and it keeps degrading as k increases. See more here.

# %%
# 5.0 Perform clustering with 6 clusters
#     MinBatchKMEans converges very fast:

model = KMeans(
                n_clusters=6,
                max_iter=1000
              )

# %%
# 5.1
model.fit(clus_read)
# Out:
# KMeans(max_iter=1000, n_clusters=6)

# %%
cl_label = model.predict(clus_read)

# %%
np.min(cl_label)
# Out:
# 0

# %%
cl_label[:20]
# Out:
# array([4, 0, 0, 4, 4, 0, 0, 4, 0, 0, 0, 4, 0, 1, 4, 4, 4, 0, 0, 0],
#       dtype=int32)

# %%
model.labels_
# Out:
# array([4, 0, 0, ..., 2, 0, 3], dtype=int32)

# %%
# 5.2 About the model
#     We get labels about all
#     45-lakh rows not just 1-lakh
#     or bacth-size

len(model.labels_)
print()

# 5.2.1
model.inertia_
print()
# Out:
# 4534327
# 5526.91015625

# %% [markdown]
# ### I. Silhoutte plot

# %%
# 5.3 Create a new column
#     in 'fpr' memap

clus_read = np.hstack(
                     [ clus_read,
                       model.labels_.reshape(model.labels_.shape[0],1)
                     ]
                )

# 5.3.1 Check
clus_read.shape
# Out:
# (4534327, 4)

# %% [markdown]
# #### Silhoutte score calculation

# %%
# 6.0 Shuffle data
x = np.arange(clus_read.shape[0])
np.random.shuffle(x)
clus_read = clus_read[x]

# %%
# 3.3 Mean silhoutte score
data_size = 100000
silhouette_score(
                 clus_read[:data_size,:2],
                 model.labels_[:data_size],
                 sample_size=50000   # For calculation of silhoutte score
                 )
# Out:
# -0.0597115516189606

# %% [markdown]
# #### Silhoutte plot

# %%
# 4.0
# Ref: https://www.scikit-yb.org/en/latest/api/cluster/silhouette.html

visualizer = SilhouetteVisualizer(
                                  model,
                                  colors='yellowbrick'
                                  )

# %%
# 4.1
fig = plt.figure(figsize= (10,10))
start = time.time()
_= visualizer.fit(clus[:10000])        # Fit the data to the visualizer
_= visualizer.show()        # Finalize and render the figure
end = time.time()
(end-start)/60
# Out:
# 0.044609351952870684

# %% [markdown]
# ### J. Cluster centroids on map

# %%
# 5.0
centroids = model.cluster_centers_

# 5.0.1
centroids  # 6-rows, one for each cluster
# Out:
# array([[ 40.7325  , -73.99702 ],
#        [ 40.665043, -73.762314],
#        [ 40.79538 , -73.871185],
#        [ 40.68713 , -73.964745],
#        [ 40.76622 , -73.97083 ],
#        [ 40.698444, -74.202545]], dtype=float32)

# %%
# 5.1 Transform  centroids to a DataFrame:

clocation = pd.DataFrame(
                         centroids,
                         columns = ["Latitude", "Longitude"]
                         )

# 5.1.1
clocation    # Six rows, one for each cluster
# Out:
#     Latitude  Longitude
# 0  40.732498 -73.997017
# 1  40.665043 -73.762314
# 2  40.795380 -73.871185
# 3  40.687130 -73.964745
# 4  40.766220 -73.970833
# 5  40.698444 -74.202545

# %%
# 5.2 What are mean centroid values:

lat_mean = clocation['Latitude'].mean()
long_mean = clocation['Longitude'].mean()

# %%
# 5.2.1
lat_mean
print("")
long_mean
# Out:
# 40.724117
# -73.96144

# %%
# 5.3 Converting centroid into list of lists:

centroid = clocation.values.tolist()
centroid
# Out:
# [[40.73249816894531, -73.99701690673828],
#  [40.665042877197266, -73.76231384277344],
#  [40.795379638671875, -73.87118530273438],
#  [40.687129974365234, -73.9647445678711],
#  [40.76622009277344, -73.97083282470703],
#  [40.69844436645508, -74.20254516601562]]

# %%
# 5.1 Plotting the centroids on google map using Folium library.
#     Create Map object:

map = folium.Map(
                  # Center the map here
                  location=[lat_mean,long_mean],
                  zoom_start = 10
                )

# %%
# 5.5.1 Display the map:
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6f825cad1691891b4e366f25781b047 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6f825cad1691891b4e366f25781b047&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d6f825cad1691891b4e366f25781b047 = L.map(
#                 &quot;map_d6f825cad1691891b4e366f25781b047&quot;,
#                 {
#                     center: [40.724117279052734, -73.96144104003906],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c63c71d5ed34cfd10eb1b8460c0ab63e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 5.2 Add further to properties of Map object:
#     Draw as many markers as there are cnetroids:

for point in range(0, len(centroid)):
  _=folium.Marker(
                      centroid[point],
                      popup = centroid[point]
                      ).add_to(map)

# %%
# 5.3 Draw now the map with markers:
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6f825cad1691891b4e366f25781b047 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6f825cad1691891b4e366f25781b047&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d6f825cad1691891b4e366f25781b047 = L.map(
#                 &quot;map_d6f825cad1691891b4e366f25781b047&quot;,
#                 {
#                     center: [40.724117279052734, -73.96144104003906],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c63c71d5ed34cfd10eb1b8460c0ab63e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
#
#             var marker_220d45c565d1047b694a497c4af77307 = L.marker(
#                 [40.73249816894531, -73.99701690673828],
#                 {}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
#
#         var popup_dc0565237331262ccd6657783d9f8e24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7ca3fcedbbb3acb4805dfaa79b6b1eaa = $(`&lt;div id=&quot;html_7ca3fcedbbb3acb4805dfaa79b6b1eaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.73249816894531, -73.99701690673828]&lt;/div&gt;`)[0];
#             popup_dc0565237331262ccd6657783d9f8e24.setContent(html_7ca3fcedbbb3acb4805dfaa79b6b1eaa);
#
#
#         marker_220d45c565d1047b694a497c4af77307.bindPopup(popup_dc0565237331262ccd6657783d9f8e24)
#         ;
#
#
#
#
#             var marker_22c330ca855acb6769d1247a24b21ae9 = L.marker(
#                 [40.665042877197266, -73.76231384277344],
#                 {}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
#
#         var popup_b3cafdaf5637ffceb011dcc0588979cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a4e3b51e0c32ef01dc3045fd60869d4d = $(`&lt;div id=&quot;html_a4e3b51e0c32ef01dc3045fd60869d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.665042877197266, -73.76231384277344]&lt;/div&gt;`)[0];
#             popup_b3cafdaf5637ffceb011dcc0588979cf.setContent(html_a4e3b51e0c32ef01dc3045fd60869d4d);
#
#
#         marker_22c330ca855acb6769d1247a24b21ae9.bindPopup(popup_b3cafdaf5637ffceb011dcc0588979cf)
#         ;
#
#
#
#
#             var marker_3ab0796194f9c47af70c44d71297ae57 = L.marker(
#                 [40.795379638671875, -73.87118530273438],
#                 {}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
#
#         var popup_dbcdb5befca370c6cac865d452a95195 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7385c6a6bd2282004dc56e308eea677f = $(`&lt;div id=&quot;html_7385c6a6bd2282004dc56e308eea677f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.795379638671875, -73.87118530273438]&lt;/div&gt;`)[0];
#             popup_dbcdb5befca370c6cac865d452a95195.setContent(html_7385c6a6bd2282004dc56e308eea677f);
#
#
#         marker_3ab0796194f9c47af70c44d71297ae57.bindPopup(popup_dbcdb5befca370c6cac865d452a95195)
#         ;
#
#
#
#
#             var marker_52a488827fe5f858fa114d290da00124 = L.marker(
#                 [40.687129974365234, -73.9647445678711],
#                 {}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
#
#         var popup_7401c93ef06987f8412896fe639ada9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5944fddc576760c01705be2c80605a1 = $(`&lt;div id=&quot;html_f5944fddc576760c01705be2c80605a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.687129974365234, -73.9647445678711]&lt;/div&gt;`)[0];
#             popup_7401c93ef06987f8412896fe639ada9b.setContent(html_f5944fddc576760c01705be2c80605a1);
#
#
#         marker_52a488827fe5f858fa114d290da00124.bindPopup(popup_7401c93ef06987f8412896fe639ada9b)
#         ;
#
#
#
#
#             var marker_4ac6f835b1c1d13cc7f804ee84309fd2 = L.marker(
#                 [40.76622009277344, -73.97083282470703],
#                 {}
#             ).addTo(map_d6f825cad1691891b4e366f25781b047);
#
#
#         var popup_10618a616e0d4319867d3a5ea0c9548b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5db183ab4a3f82cc664e222aeaba9730 = $(`&lt;div id=&quot;html_5db183ab4a3f82cc664e222aeaba9730&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.76622009277344, -73.97083282470703]&lt;/div&gt;`)[0];
#             popup_10618a616e0d4319867d3a5ea0c9548b.setContent(html_5db183ab4a3f82cc664e222aeaba9730);
#
#
#         marker_4ac6f835b1c1d13cc7f804ee84309fd2.bindPopup(popup_10618a616e0d4319867d3a5ea0c9548b)
#         ;
#
#
#
#
#             var marker_a8e72d01430b4b5ac7ee32f45b0adb95 = L.marker(
#                 [40.69844436645508, -74.20254516601562],
#                 {}
#             ).addTo(map_d6f825cad1691891b4e366f2578

# %% [markdown]
# ### K. Conclusions

# %% [markdown]
# We can see that all the six centroids have been plotted on the map. How are these centroids helpful for Uber?
#
# >    Uber can use these centroids as their hubs. Whenever Uber receives a new ride request, they can check the closeness with each of these centroids. Whichever particular centroid is closer, Uber can direct the vehicle from that particular location to the customer location.<br>
#
# >    Uber has many drivers and provides services to many locations. If Uber knows the hub (particular centroid), and if they are getting a lot of ride request then strategically they can place their drivers in better locations wherein their probability of getting a ride request is greater. This will help Uber to serve the customer faster as vehicles are placed closer to the location and also help to grow their business.<br>
#
# >   Uber can make use of these centroids for the optimal placing of their vehicles. They can find which centroid at which part of the day have more ride requests. For example, if Uber gets more request from centroid 0 (cluster 1) at 11 AM, but far fewer requests from centroid 3 (cluster 4), then they can redirect the vehicles to cluster 1 from cluster 4 (if there is an increased vehicle presence in cluster 4).<br>
#
# >   Uber can use these centroids for optimal pricing by analyzing which cluster deals with maximum requests, peak times etc. Suppose they don’t have many vehicles available to be sent to a particular location (more demand), then they can do optimal pricing as demand is high and supply is less. <br>

# %% [markdown]
# ### L. Misc

# %%
# https://seaborn.pydata.org/generated/seaborn.catplot.html
import seaborn as sns
_= sns.catplot(
                   data = clus,
                   x = 'Clusters',
                   kind = 'count',
                   size = 7,
                   order = [2,0,4,5,1,3] # Order of display
                  )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3750: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-218-7c667876881e> in <module>
#       6                    kind = 'count',
#       7                    size = 7,
# ----> 8                    order = [2,0,4,5,1,3] # Order of display
#       9                   )
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# -> 3792     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793     if (
#    3794         order is not None
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     142             # See if we need to get variables from `data`
#     143             if data is not None:
# --> 144                 x = data.get(x, x)
#     145                 y = data.get(y, y)
#     146                 hue = data.get(hue, hue)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get'

# %%
# 3.0 Predicting on a new location
new_location = [(40.6556,-73.5631)]
kmeans.predict(new_location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-219-f5b600d0d041> in <module>
#       1 # 3.0 Predicting on a new location
#       2 new_location = [(40.6556,-73.5631)]
# ----> 3 kmeans.predict(new_location)
#
# NameError: name 'kmeans' is not defined

# %%
####### I am done ################
